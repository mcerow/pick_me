# %%
import requests
import re
from bs4 import BeautifulSoup
import bs4
import pandas as pd
import numpy as np
import json
import urllib
import time

import warnings
warnings.simplefilter('ignore')

# %%
# %%capture

from tqdm import tqdm_notebook as tqdm
from tqdm import tnrange
tqdm().pandas()

# %%
def get_playerids(data):
    all_ids = []
    for i in data:
        xid = str(i)
        xid = xid.split('"')[5]
        all_ids.append(xid)
    return all_ids

# %%
def names(data):
    all_names = []
    count = 0
    for i in data:
        all_names.append(data[count].get_text())
        count += 1
    return all_names

# %%
def get_position(data):
    all_positions = []
    count = 0
    for i in data:
        if count in range(len(data)):
            all_positions.append(data[count].get_text())
            count += 12
    
    return all_positions

# %%
def get_school(data):
    all_schools = []
    count = 1
    for i in data:
        if count in range(len(data)):
            all_schools.append(data[count].get_text())
            count += 12
    
    return all_schools

# %%
def get_stats_links(data):
    stats_links = []
    count = 0
    for i in data:
        if count in range(len(data)):
            link = data[count]
            link = str(link)
            link = link.split('<')
            link = link[2]
            link = link.lstrip('a href =')
            link = link.rstrip('> College Stats')
            link = link.replace('"', '')
            stats_links.append(link)
            count += 9
        else:
            continue
    return stats_links

# %%
def get_height(data):
    all_heights = []
    count = 3
    for i in data:
        if count in range(len(data)):
            all_heights.append(data[count].get_text())
            count += 12
    
    return all_heights

# %%
def get_weight(data):
    all_weights = []
    count = 4
    for i in data:
        if count in range(len(data)):
            all_weights.append(data[count].get_text())
            count += 12
    
    return all_weights

# %%
def get_40yd(data):
    all_40yds = []
    count = 5
    for i in data:
        if count in range(len(data)):
            all_40yds.append(data[count].get_text())
            count += 12
    
    return all_40yds

# %%
def get_vertical(data):
    all_verticals = []
    count = 6
    for i in data:
        if count in range(len(data)):
            all_verticals.append(data[count].get_text())
            count += 12
    
    return all_verticals

# %%
def get_bench(data):
    all_bench = []
    count = 7
    for i in data:
        if count in range(len(data)):
            all_bench.append(data[count].get_text())
            count += 12
    
    return all_bench

# %%
def get_broadjump(data):
    all_jumps = []
    count = 8
    for i in data:
        if count in range(len(data)):
            all_jumps.append(data[count].get_text())
            count += 12
    
    return all_jumps

# %%
def get_3cone(data):
    all_cones = []
    count = 9
    for i in data:
        if count in range(len(data)):
            all_cones.append(data[count].get_text())
            count += 12
    
    return all_cones

# %%
def get_shuttle(data):
    all_shuttles = []
    count = 10
    for i in data:
        if count in range(len(data)):
            all_shuttles.append(data[count].get_text())
            count += 12
    
    return all_shuttles

# %%
def get_draft(data):
    all_draft = []
    count = 11
    for i in data:
        if count in range(len(data)):
            all_draft.append(data[count].get_text())
            count += 12
    
    return all_draft

# %%
def get_combine_history(links):
    SearchLinks = []
    PlayerNames = []
    Positions = []
    Schools = []
    StatsLinks = []
    Heights = []
    Weights = []
    _40yds = []
    Verticals = []
    Benched = []
    BroadJumps = []
    _3cones = []
    Shuttles = []
    Drafts = []
    
    for link in tqdm(links):
        url = link
        html_page = requests.get(url) 
        soup = BeautifulSoup(html_page.content, 'html.parser')

        player_container = soup.find('tbody')
        player_name = player_container.findAll('th', scope='row')
        player_deets = player_container.findAll('td')
        stats_finder = player_container.findAll('td', {'class':'right'})
           
        for name in names(player_name):
            PlayerNames.append(name)
            SearchLinks.append(str(link))

        for position in get_position(player_deets):
            Positions.append(position)
     
        for school in get_school(player_deets):
            Schools.append(school)
        
        for statlink in get_stats_links(stats_finder):
            StatsLinks.append(statlink)

        for height in get_height(player_deets):
            Heights.append(height)

        for weight in get_weight(player_deets):
            Weights.append(weight)       

        for _40yd in get_40yd(player_deets):
            _40yds.append(_40yd)
            
        for vertical in get_vertical(player_deets):
            Verticals.append(vertical)

        for bench in get_bench(player_deets):
            Benched.append(bench)

        for jump in get_broadjump(player_deets):
            BroadJumps.append(jump)

        for cone in get_3cone(player_deets):
            _3cones.append(cone)      

        for shuttle in get_shuttle(player_deets):
            Shuttles.append(shuttle)

        for draft in get_draft(player_deets):
            Drafts.append(draft)

        time.sleep(.5)

    combine_dictionary = {'Link': SearchLinks, 'PlayerName': PlayerNames, 'Position': Positions, 'School': Schools, 
                          'CollegeStats': StatsLinks, 'Height': Heights, 'Weight': Weights, '40yd': _40yds, 
                          'Vertical': Verticals, 'Bench': Benched, 'BroadJump': BroadJumps, '3Cone': _3cones, 
                          'Shuttle': Shuttles, 'Drafted': Drafts}
    return combine_dictionary

# %%
combine_years = range(2000, 2021)
links = []

for year in combine_years:
    link = 'https://www.pro-football-reference.com/draft/' + str(year) + '-combine.htm'
    links.append(link)

# %%
nfl_combine_df = pd.DataFrame(get_combine_history(links))
nfl_combine_df
# Out:
# HBox(children=(FloatProgress(value=0.0, max=21.0), HTML(value='')))
#                                                    Link         PlayerName  \
# 0     https://www.pro-football-reference.com/draft/2...       John Abraham
# 1     https://www.pro-football-reference.com/draft/2...    Shaun Alexander
# 2     https://www.pro-football-reference.com/draft/2...     Darnell Alford
# 3     https://www.pro-football-reference.com/draft/2...       Kyle Allamon
# 4     https://www.pro-football-reference.com/draft/2...   Rashard Anderson
# ...                                                 ...                ...
# 6888  https://www.pro-football-reference.com/draft/2...        D.J. Wonnum
# 6889  https://www.pro-football-reference.com/draft/2...  Dom Wood-Anderson
# 6890  https://www.pro-football-reference.com/draft/2...     David Woodward
# 6891  https://www.pro-football-reference.com/draft/2...        Chase Young
# 6892  https://www.pro-football-reference.com/draft/2...      Jabari Zuniga
#
#      Position          School  \
# 0         OLB  South Carolina
# 1          RB         Alabama
# 2          OT     Boston Col.
# 3          TE      Texas Tech
# 4          CB   Jackson State
# ...       ...             ...
# 6888       DL  South Carolina
# 6889       TE       Tennessee
# 6890       LB      Utah State
# 6891       DL      Ohio State
# 6892       DL         Florida
#
#                                            CollegeStats Height Weight  40yd  \
# 0                                                   /td    6-4    252  4.55
# 1     https://www.sports-reference.com/cfb/players/s...    6-0    218  4.58
# 2                                                   /td    6-4    334  5.56
# 3                                                   /td    6-2    253  4.97
# 4                                                   /td    6-2    206  4.55
# ...                                                 ...    ...    ...   ...
# 6888  https://www.sports-reference.com/cfb/players/d...    6-5    258  4.73
# 6889  https://www.sports-reference.com/cfb/players/d...    6-4    261  4.92
# 6890  https://www.sports-reference.com/cfb/players/d...    6-2    230  4.79
# 6891  https://www.sports-reference.com/cfb/players/c...    6-5    264
# 6892  https://www.sports-reference.com/cfb/players/j...    6-3    264  4.64
#
#      Vertical Bench BroadJump 3Cone Shuttle  \
# 0
# 1
# 2        25.0    23        94  8.48    4.98
# 3        29.0             104  7.29    4.49
# 4        34.0             123  7.18    4.15
# ...       ...   ...       ...   ...     ...
# 6888     34.5    20       123  7.25    4.44
# 6889     35.0             119
# 6890     33.5    16       114  7.34    4.37
# 6891
# 6892     33.0    29       127
#
#                                            Drafted
# 0           New York Jets / 1st / 13th pick / 2000
# 1        Seattle Seahawks / 1st / 19th pick / 2000
# 2     Kansas City Chiefs / 6th / 188th pick / 2000
# 3
# 4       Carolina Panthers / 1st / 23rd pick / 2000
# ...                                            ...
# 6888   Minnesota Vikings / 4th / 117th pick / 2020
# 6889
# 6890
# 6891   Washington Redskins / 1st / 2nd pick / 2020
# 6892        New York Jets / 3rd / 79th pick / 2020
#
# [6893 rows x 14 columns]

# %%
nfl_combine_df['CombineYear'] = nfl_combine_df['Link'].map(lambda x: x.split('/'))
nfl_combine_df['CombineYear'] = nfl_combine_df['CombineYear'].map(lambda x: x[-1])
nfl_combine_df['CombineYear'] = nfl_combine_df['CombineYear'].map(lambda x: x.rstrip('-combine.htm'))
nfl_combine_df['CombineYear'].head()
# Out:
# 0    2000
# 1    2000
# 2    2000
# 3    2000
# 4    2000
# Name: CombineYear, dtype: object

# %%
nfl_combine_df.shape
# Out:
# (6893, 15)

# %%
nfl_combine_df.columns
# Out:
# Index(['Link', 'PlayerName', 'Position', 'School', 'CollegeStats', 'Height',
#        'Weight', '40yd', 'Vertical', 'Bench', 'BroadJump', '3Cone', 'Shuttle',
#        'Drafted', 'CombineYear'],
#       dtype='object')

# %%
nfl_combine_df['Drafted'].head()
# Out:
# 0          New York Jets / 1st / 13th pick / 2000
# 1       Seattle Seahawks / 1st / 19th pick / 2000
# 2    Kansas City Chiefs / 6th / 188th pick / 2000
# 3
# 4      Carolina Panthers / 1st / 23rd pick / 2000
# Name: Drafted, dtype: object

# %%
nfl_combine_df['Draft Team'] = nfl_combine_df['Drafted']
nfl_combine_df['Draft Team'] = nfl_combine_df['Draft Team'].map(lambda x: x.split('/'))
nfl_combine_df['Draft Team'] = nfl_combine_df['Draft Team'].map(lambda x: x[0])
nfl_combine_df['Draft Team'].head()
# Out:
# 0         New York Jets
# 1      Seattle Seahawks
# 2    Kansas City Chiefs
# 3
# 4     Carolina Panthers
# Name: Draft Team, dtype: object

# %%
nfl_combine_df['Round'] = nfl_combine_df['Drafted']
nfl_combine_df['Round'] = nfl_combine_df['Round'].map(lambda x: x.split('/'))
nfl_combine_df['Round'] = nfl_combine_df['Round'].map(lambda x: x[1] if 1 in range(len(x)) else "Not Drafted")
nfl_combine_df['Round'].head()
# Out:
# 0           1st
# 1           1st
# 2           6th
# 3    Not Drafted
# 4           1st
# Name: Round, dtype: object

# %%
nfl_combine_df['Round'].value_counts()
# Out:
# Not Drafted    2416
#  3rd            708
#  4th            701
#  1st            662
#  2nd            647
#  5th            646
#  6th            569
#  7th            544
# Name: Round, dtype: int64

# %%
nfl_combine_df['Pick'] = nfl_combine_df['Drafted']
nfl_combine_df['Pick'] = nfl_combine_df['Pick'].map(lambda x: x.split('/'))
nfl_combine_df['Pick'] = nfl_combine_df['Pick'].map(lambda x: x[2] if 2 in range(len(x)) else "Not Drafted")
nfl_combine_df['Pick'].head()
# Out:
# 0      13th pick
# 1      19th pick
# 2     188th pick
# 3     Not Drafted
# 4      23rd pick
# Name: Pick, dtype: object

# %%
nfl_combine_df['Pick'].value_counts()
# Out:
# Not Drafted     2416
#  52nd pick        21
#  88th pick        21
#  37th pick        21
#  62nd pick        21
#                 ...
#  258th pick        1
#  259th pick        1
#  260th pick        1
#  262nd pick        1
#  257th pick        1
# Name: Pick, Length: 262, dtype: int64

# %%
nfl_combine_df['Draft Year'] = nfl_combine_df['Drafted']
nfl_combine_df['Draft Year'] = nfl_combine_df['Draft Year'].map(lambda x: x.split('/'))
nfl_combine_df['Draft Year'] = nfl_combine_df['Draft Year'].map(lambda x: x[3] if 3 in range(len(x)) else "Not Drafted")
nfl_combine_df['Draft Year'].head()
# Out:
# 0           2000
# 1           2000
# 2           2000
# 3    Not Drafted
# 4           2000
# Name: Draft Year, dtype: object

# %%
nfl_combine_df.head()
# Out:
#                                                 Link        PlayerName  \
# 0  https://www.pro-football-reference.com/draft/2...      John Abraham
# 1  https://www.pro-football-reference.com/draft/2...   Shaun Alexander
# 2  https://www.pro-football-reference.com/draft/2...    Darnell Alford
# 3  https://www.pro-football-reference.com/draft/2...      Kyle Allamon
# 4  https://www.pro-football-reference.com/draft/2...  Rashard Anderson
#
#   Position          School                                       CollegeStats  \
# 0      OLB  South Carolina                                                /td
# 1       RB         Alabama  https://www.sports-reference.com/cfb/players/s...
# 2       OT     Boston Col.                                                /td
# 3       TE      Texas Tech                                                /td
# 4       CB   Jackson State                                                /td
#
#   Height Weight  40yd Vertical Bench BroadJump 3Cone Shuttle  \
# 0    6-4    252  4.55
# 1    6-0    218  4.58
# 2    6-4    334  5.56     25.0    23        94  8.48    4.98
# 3    6-2    253  4.97     29.0             104  7.29    4.49
# 4    6-2    206  4.55     34.0             123  7.18    4.15
#
#                                         Drafted CombineYear  \
# 0        New York Jets / 1st / 13th pick / 2000        2000
# 1     Seattle Seahawks / 1st / 19th pick / 2000        2000
# 2  Kansas City Chiefs / 6th / 188th pick / 2000        2000
# 3                                                      2000
# 4    Carolina Panthers / 1st / 23rd pick / 2000        2000
#
#             Draft Team        Round          Pick   Draft Year
# 0       New York Jets          1st     13th pick          2000
# 1    Seattle Seahawks          1st     19th pick          2000
# 2  Kansas City Chiefs          6th    188th pick          2000
# 3                       Not Drafted   Not Drafted  Not Drafted
# 4   Carolina Panthers          1st     23rd pick          2000

# %%
nfl_combine_df.shape
# Out:
# (6893, 19)

# %%
nfl_combine_df.columns
# Out:
# Index(['Link', 'PlayerName', 'Position', 'School', 'CollegeStats', 'Height',
#        'Weight', '40yd', 'Vertical', 'Bench', 'BroadJump', '3Cone', 'Shuttle',
#        'Drafted', 'CombineYear', 'Draft Team', 'Round', 'Pick', 'Draft Year'],
#       dtype='object')

# %%
nfl_combine_df.to_csv('2000-2020_nfl_combine_data.csv')

# %% [markdown]
# # Get College Stats

# %%
college_stats = nfl_combine_df[nfl_combine_df['CollegeStats'] != '/td']
college_stats = list(college_stats['CollegeStats'])
print(len(college_stats))
sorted(college_stats)
# Out:
# 5486
# ['https://www.sports-reference.com/cfb/players/aaron-burbridge-1.html',
#  'https://www.sports-reference.com/cfb/players/aaron-colvin-1.html',
#  'https://www.sports-reference.com/cfb/players/aaron-curry-1.html',
#  'https://www.sports-reference.com/cfb/players/aaron-davis-4.html',
#  'https://www.sports-reference.com/cfb/players/aaron-dobson-1.html',
#  'https://www.sports-reference.com/cfb/players/aaron-donald-1.html',
#  'https://www.sports-reference.com/cfb/players/aaron-francisco-1.html',
#  'https://www.sports-reference.com/cfb/players/aaron-fuller-1.html',
#  'https://www.sports-reference.com/cfb/players/aaron-hernandez-1.html',
#  'https://www.sports-reference.com/cfb/players/aaron-hester-1.html',
#  'https://www.sports-reference.com/cfb/players/aaron-hunt-2.html',
#  'https://www.sports-reference.com/cfb/players/aaron-jones-6.html',
#  'https://www.sports-reference.com/cfb/players/aaron-kelly-1.html',
#  'https://www.sports-reference.com/cfb/players/aaron-lockett-1.html',
#  'https://www.sports-reference.com/cfb/players/aaron-lynch-1.html',
#  'https://www.sports-reference.com/cfb/players/aaron-maybin-1.html',
#  'https://www.sports-reference.com/cfb/players/aaron-murray-1.html',
#  'https://www.sports-reference.com/cfb/players/aaron-pettrey-1.html',
#  'https://www.sports-reference.com/cfb/players/aaron-rodgers-1.html',
#  'https://www.sports-reference.com/cfb/players/aaron-ross-1.html',
#  'https://www.sports-reference.com/cfb/players/aaron-rouse-1.html',
#  'https://www.sports-reference.com/cfb/players/aaron-schobel-1.html',
#  'https://www.sports-reference.com/cfb/players/aaron-shea-1.html',
#  'https://www.sports-reference.com/cfb/players/aaron-walker-2.html',
#  'https://www.sports-reference.com/cfb/players/aaron-williams-2.html',
#  'https://www.sports-reference.com/cfb/players/abdual-howard-1.html',
#  'https://www.sports-reference.com/cfb/players/abdul-hodge-1.html',
#  'https://www.sports-reference.com/cfb/players/abraham-elimimian-1.html',
#  'https://www.sports-reference.com/cfb/players/abraham-wright-1.html',
#  'https://www.sports-reference.com/cfb/players/abry-jones-1.html',
#  'https://www.sports-reference.com/cfb/players/ace-sanders-1.html',
#  'https://www.sports-reference.com/cfb/players/adalius-thomas-1.html',
#  'https://www.sports-reference.com/cfb/players/adam-archuleta-1.html',
#  'https://www.sports-reference.com/cfb/players/adam-bishop-1.html',
#  'https://www.sports-reference.com/cfb/players/adam-bisnowaty-1.html',
#  'https://www.sports-reference.com/cfb/players/adam-carriker-1.html',
#  'https://www.sports-reference.com/cfb/players/adam-finley-1.html',
#  'https://www.sports-reference.com/cfb/players/adam-gotsis-1.html',
#  'https://www.sports-reference.com/cfb/players/adam-graessle-1.html',
#  'https://www.sports-reference.com/cfb/players/adam-jennings-1.html',
#  'https://www.sports-reference.com/cfb/players/adam-muema-1.html',
#  'https://www.sports-reference.com/cfb/players/adam-podlesh-1.html',
#  'https://www.sports-reference.com/cfb/players/adam-seward-1.html',
#  'https://www.sports-reference.com/cfb/players/adam-tafralis-1.html',
#  'https://www.sports-reference.com/cfb/players/adam-wulfeck-1.html',
#  'https://www.sports-reference.com/cfb/players/adamm-oliver-1.html',
#  'https://www.sports-reference.com/cfb/players/adarius-bowman-1.html',
#  'https://www.sports-reference.com/cfb/players/ade-aruna-1.html',
#  'https://www.sports-reference.com/cfb/players/adell-duckett-1.html',
#  'https://www.sports-reference.com/cfb/players/adimchinobi-echemandu-1.html',
#  'https://www.sports-reference.com/cfb/players/adolphus-washington-1.html',
#  'https://www.sports-reference.com/cfb/players/adoree-jackson-1.html',
#  'https://www.sports-reference.com/cfb/players/adrian-amos-1.html',
#  'https://www.sports-reference.com/cfb/players/adrian-arrington-1.html',
#  'https://www.sports-reference.com/cfb/players/adrian-burnette-1.html',
#  'https://www.sports-reference.com/cfb/players/adrian-bushell-2.html',
#  'https://www.sports-reference.com/cfb/players/adrian-clayborn-1.html',
#  'https://www.sports-reference.com/cfb/players/adrian-grady-1.html',
#  'https://www.sports-reference.com/cfb/players/adrian-hubbard-1.html',
#  'https://www.sports-reference.com/cfb/players/adrian-jones-1.html',
#  'https://www.sports-reference.com/cfb/players/adrian-madise-1.html',
#  'https://www.sports-reference.com/cfb/players/adrian-moten-1.html',
#  'https://www.sports-reference.com/cfb/players/adrian-peterson-1.html',
#  'https://www.sports-reference.com/cfb/players/adrian-taylor-1.html',
#  'https://www.sports-reference.com/cfb/players/ahkello-witherspoon-1.html',
#  'https://www.sports-reference.com/cfb/players/ahmaad-galloway-1.html',
#  'https://www.sports-reference.com/cfb/players/ahmad-black-1.html',
#  'https://www.sports-reference.com/cfb/players/ahmad-bradshaw-1.html',
#  'https://www.sports-reference.com/cfb/players/ahmad-carroll-1.html',
#  'https://www.sports-reference.com/cfb/players/ahmad-dixon-1.html',
#  'https://www.sports-reference.com/cfb/players/ahtyba-rubin-1.html',
#  'https://www.sports-reference.com/cfb/players/airese-currie-1.html',
#  'https://www.sports-reference.com/cfb/players/aj-brown-3.html',
#  'https://www.sports-reference.com/cfb/players/aj-cann-1.html',
#  'https://www.sports-reference.com/cfb/players/aj-davis-1.html',
#  'https://www.sports-reference.com/cfb/players/aj-dillon-1.html',
#  'https://www.sports-reference.com/cfb/players/aj-edds-1.html',
#  'https://www.sports-reference.com/cfb/players/aj-epenesa-1.html',
#  'https://www.sports-reference.com/cfb/players/aj-green-1.html',
#  'https://www.sports-reference.com/cfb/players/aj-green-4.html',
#  'https://www.sports-reference.com/cfb/players/aj-hawk-1.html',
#  'https://www.sports-reference.com/cfb/players/aj-jefferson-1.html',
#  'https://www.sports-reference.com/cfb/players/aj-jenkins-1.html',
#  'https://www.sports-reference.com/cfb/players/aj-klein-1.html',
#  'https://www.sports-reference.com/cfb/players/aj-mccarron-1.html',
#  'https://www.sports-reference.com/cfb/players/aj-nicholson-1.html',
#  'https://www.sports-reference.com/cfb/players/aj-stamps-1.html',
#  'https://www.sports-reference.com/cfb/players/aj-terrell-1.html',
#  'https://www.sports-reference.com/cfb/players/akeem-ayers-1.html',
#  'https://www.sports-reference.com/cfb/players/akeem-davis-gaither-1.html',
#  'https://www.sports-reference.com/cfb/players/akeem-dent-1.html',
#  'https://www.sports-reference.com/cfb/players/akeem-spence-1.html',
#  'https://www.sports-reference.com/cfb/players/akin-ayodele-1.html',
#  'https://www.sports-reference.com/cfb/players/akrum-wadley-1.html',
#  'https://www.sports-reference.com/cfb/players/al-blades-1.html',
#  'https://www.sports-reference.com/cfb/players/al-bond-1.html',
#  'https://www.sports-reference.com/cfb/players/al-quadin-muhammad-1.html',
#  'https://www.sports-reference.com/cfb/players/al-woods-2.html',
#  'https://www.sports-reference.com/cfb/players/alameda-taamu-1.html',
#  'https://www.sports-reference.com/cfb/players/alan-branch-1.html',
#  'https://www.sports-reference.com/cfb/players/alan-harper-1.html',
#  'https://www.sports-reference.com/cfb/players/alan-zemaitis-1.html',
#  'https://www.sports-reference.com/cfb/players/alani-fua-1.html',
#  'https://www.sports-reference.com/cfb/players/albert-huggins-1.html',
#  'https://www.sports-reference.com/cfb/players/albert-mcclellan-1.html',
#  'https://www.sports-reference.com/cfb/players/albert-okwuegbunam-1.html',
#  'https://www.sports-reference.com/cfb/players/albert-wilson-1.html',
#  'https://www.sports-reference.com/cfb/players/aldon-smith-1.html',
#  'https://www.sports-reference.com/cfb/players/aldrick-robinson-1.html',
#  'https://www.sports-reference.com/cfb/players/alec-ingold-1.html',
#  'https://www.sports-reference.com/cfb/players/alec-lemon-1.html',
#  'https://www.sports-reference.com/cfb/players/alec-ogletree-1.html',
#  'https://www.sports-reference.com/cfb/players/aleric-mullins-1.html',
#  'https://www.sports-reference.com/cfb/players/alex-anzalone-1.html',
#  'https://www.sports-reference.com/cfb/players/alex-barnes-1.html',
#  'https://www.sports-reference.com/cfb/players/alex-barron-1.html',
#  'https://www.sports-reference.com/cfb/players/alex-bars-1.html',
#  'https://www.sports-reference.com/cfb/players/alex-brink-1.html',
#  'https://www.sports-reference.com/cfb/players/alex-brown-1.html',
#  'https://www.sports-reference.com/cfb/players/alex-carrington-1.html',
#  'https://www.sports-reference.com/cfb/players/alex-carter-1.html',
#  'https://www.sports-reference.com/cfb/players/alex-collins-1.html',
#  'https://www.sports-reference.com/cfb/players/alex-dunnachie-1.html',
#  'https://www.sports-reference.com/cfb/players/alex-green-2.html',
#  'https://www.sports-reference.com/cfb/players/alex-haynes-1.html',
#  'https://www.sports-reference.com/cfb/players/alex-henery-1.html',
#  'https://www.sports-reference.com/cfb/players/alex-highsmith-1.html',
#  'https://www.sports-reference.com/cfb/players/alex-holmes-1.html',
#  'https://www.sports-reference.com/cfb/players/alex-lewis-1.html',
#  'https://www.sports-reference.com/cfb/players/alex-lewis-2.html',
#  'https://www.sports-reference.com/cfb/players/alex-lincoln-1.html',
#  'https://www.sports-reference.com/cfb/players/alex-mack-1.html',
#  'https://www.sports-reference.com/cfb/players/alex-magee-1.html',
#  'https://www.sports-reference.com/cfb/players/alex-mccalister-1.html',
#  'https://www.sports-reference.com/cfb/players/alex-okafor-1.html',
#  'https://www.sports-reference.com/cfb/players/alex-parsons-1.html',
#  'https://www.sports-reference.com/cfb/players/alex-redmond-1.html',
#  'https://www.sports-reference.com/cfb/players/alex-reyes-1.html',
#  'https://www.sports-reference.com/cfb/players/alex-smith-2.html',
#  'https://www.sports-reference.com/cfb/players/alex-smith-3.html',
#  'https://www.sports-reference.com/cfb/players/alex-wade-1.html',
#  'https://www.sports-reference.com/cfb/players/alex-walls-1.html',
#  'https://www.sports-reference.com/cfb/players/alexander-mattison-1.html',
#  'https://www.sports-reference.com/cfb/players/alexis-serna-1.html',
#  'https://www.sports-reference.com/cfb/players/alfonzo-dennard-1.html',
#  'https://www.sports-reference.com/cfb/players/alfred-blue-1.html',
#  'https://www.sports-reference.com/cfb/players/alfred-fincher-1.html',
#  'https://www.sports-reference.com/cfb/players/alfred-morris-1.html',
#  'https://www.sports-reference.com/cfb/players/alge-crumpler-1.html',
#  'https://www.sports-reference.com/cfb/players/ali-highsmith-1.html',
#  'https://www.sports-reference.com/cfb/players/alijah-holder-1.html',
#  'https://www.sports-reference.com/cfb/players/alize-mack-1.html',
#  'https://www.sports-reference.com/cfb/players/allen-bailey-1.html',
#  'https://www.sports-reference.com/cfb/players/allen-bradford-1.html',
#  'https://www.sports-reference.com/cfb/players/allen-hurns-1.html',
#  'https://www.sports-reference.com/cfb/players/allen-lazard-1.html',
#  'https://www.sports-reference.com/cfb/players/allen-patrick-1.html',
#  'https://www.sports-reference.com/cfb/players/allen-reisner-1.html',
#  'https://www.sports-reference.com/cfb/players/allen-robinson-1.html',
#  'https://www.sports-reference.com/cfb/players/alohi-gilman-1.html',
#  'https://www.sports-reference.com/cfb/players/alonzo-jackson-1.html',
#  'https://www.sports-reference.com/cfb/players/alonzo-russell-1.html',
#  'https://www.sports-reference.com/cfb/players/alphonso-smith-1.html',
#  'https://www.sports-reference.com/cfb/players/alric-arnett-1.html',
#  'https://www.sports-reference.com/cfb/players/alshon-jeffery-1.html',
#  'https://www.sports-reference.com/cfb/players/alterraun-verner-1.html',
#  'https://www.sports-reference.com/cfb/players/alton-robinson-1.html',
#  'https://www.sports-reference.com/cfb/players/alvin-bailey-1.html',
#  'https://www.sports-reference.com/cfb/players/alvin-bowen-1.html',
#  'https://www.sports-reference.com/cfb/players/alvin-dupree-1.html',
#  'https://www.sports-reference.com/cfb/players/alvin-kamara-1.html',
#  'https://www.sports-reference.com/cfb/players/alvin-pearman-1.html',
#  'https://www.sports-reference.com/cfb/players/amani-hooker-1.html',
#  'https://www.sports-reference.com/cfb/players/amani-oruwariye-1.html',
#  'https://www.sports-reference.com/cfb/players/amara-darboh-1.html',
#  'https://www.sports-reference.com/cfb/players/amari-cooper-1.html',
#  'https://www.sports-reference.com/cfb/players/amari-spievey-1.html',
#  'https://www.sports-reference.com/cfb/players/amarlo-herrera-1.html',
#  'https://www.sports-reference.com/cfb/players/amba-etta-tawo-1.html',
#  'https://www.sports-reference.com/cfb/players/ameer-abdullah-1.html',
#  'https://www.sports-reference.com/cfb/players/amik-robertson-1.html',
#  'https://www.sports-reference.com/cfb/players/amobi-okoye-1.html',
#  'https://www.sports-reference.com/cfb/players/andra-davis-1.html',
#  'https://www.sports-reference.com/cfb/players/andrae-thurman-1.html',
#  'https://www.sports-reference.com/cfb/players/andre-branch-1.html',
#  'https://www.sports-reference.com/cfb/players/andre-brown-1.html',
#  'https://www.sports-reference.com/cfb/players/andre-caldwell-1.html',
#  'https://www.sports-reference.com/cfb/players/andre-carter-1.html',
#  'https://www.sports-reference.com/cfb/players/andre-chachere-1.html',
#  'https://www.sports-reference.com/cfb/players/andre-davis-1.html',
#  'https://www.sports-reference.com/cfb/players/andre-dillard-1.html',
#  'https://www.sports-reference.com/cfb/players/andre-dixon-1.html',
#  'https://www.sports-reference.com/cfb/players/andre-dyson-1.html',
#  'https://www.sports-reference.com/cfb/players/andre-ellington-1.html',
#  'https://www.sports-reference.com/cfb/players/andre-fluellen-1.html',
#  'https://www.sports-reference.com/cfb/players/andre-goodman-1.html',
#  'https://www.sports-reference.com/cfb/players/andre-gurode-1.html',
#  'https://www.sports-reference.com/cfb/players/andre-hal-1.html',
#  'https://www.sports-reference.com/cfb/players/andre-hall-1.html',
#  'https://www.sports-reference.com/cfb/players/andre-james-1.html',
#  'https://www.sports-reference.com/cfb/players/andre-johnson-1.html',
#  'https://www.sports-reference.com/cfb/players/andre-king-1.html',
#  'https://www.sports-reference.com/cfb/players/andre-lott-1.html',
#  'https://www.sports-reference.com/cfb/players/andre-smith-3.html',
#  'https://www.sports-reference.com/cfb/players/andre-smith-7.html',
#  'https://www.sports-reference.com/cfb/players/andre-williams-2.html',
#  'https://www.sports-reference.com/cfb/players/andre-woodson-1.html',
#  'https://www.sports-reference.com/cfb/players/andre-woolfolk-1.html',
#  'https://www.sports-reference.com/cfb/players/andrew-billings-1.html',
#  'https://www.sports-reference.com/cfb/players/andrew-brown-2.html',
#  'https://www.sports-reference.com/cfb/players/andrew-datko-1.html',
#  'https://www.sports-reference.com/cfb/players/andrew-donnal-1.html',
#  'https://www.sports-reference.com/cfb/players/andrew-jackson-2.html',
#  'https://www.sports-reference.com/cfb/players/andrew-jackson-3.html',
#  'https://www.sports-reference.com/cfb/players/andrew-larson-1.html',
#  'https://www.sports-reference.com/cfb/players/andrew-luck-1.html',
#  'https://www.sports-reference.com/cfb/players/andrew-mcgee-1.html',
#  'https://www.sports-reference.com/cfb/players/andrew-means-1.html',
#  'https://www.sports-reference.com/cfb/players/andrew-pinnock-1.html',
#  'https://www.sports-reference.com/cfb/players/andrew-quarless-1.html',
#  'https://www.sports-reference.com/cfb/players/andrew-shull-1.html',
#  'https://www.sports-reference.com/cfb/players/andrew-thomas-2.html',
#  'https://www.sports-reference.com/cfb/players/andrew-tiller-1.html',
#  'https://www.sports-reference.com/cfb/players/andrew-van-ginkel-1.html',
#  'https://www.sports-reference.com/cfb/players/andrew-walter-1.html',
#  'https://www.sports-reference.com/cfb/players/andrew-williams-1.html',
#  'https://www.sports-reference.com/cfb/players/andrew-wingard-1.html',
#  'https://www.sports-reference.com/cfb/players/andrus-peat-1.html',
#  'https://www.sports-reference.com/cfb/players/andy-dalton-1.html',
#  'https://www.sports-reference.com/cfb/players/andy-gallik-1.html',
#  'https://www.sports-reference.com/cfb/players/andy-groom-1.html',
#  'https://www.sports-reference.com/cfb/players/andy-isabella-1.html',
#  'https://www.sports-reference.com/cfb/players/andy-janovich-1.html',
#  'https://www.sports-reference.com/cfb/players/andy-lee-1.html',
#  'https://www.sports-reference.com/cfb/players/andy-levitre-1.html',
#  'https://www.sports-reference.com/cfb/players/anfernee-jennings-1.html',
#  'https://www.sports-reference.com/cfb/players/angelo-blackson-1.html',
#  'https://www.sports-reference.com/cfb/players/angelo-craig-1.html',
#  'https://www.sports-reference.com/cfb/players/angelo-crowell-1.html',
#  'https://www.sports-reference.com/cfb/players/anquan-boldin-1.html',
#  'https://www.sports-reference.com/cfb/players/anthony-allen-1.html',
#  'https://www.sports-reference.com/cfb/players/anthony-alridge-1.html',
#  'https://www.sports-reference.com/cfb/players/anthony-arline-1.html',
#  'https://www.sports-reference.com/cfb/players/anthony-averett-1.html',
#  'https://www.sports-reference.com/cfb/players/anthony-barr-1.html',
#  'https://www.sports-reference.com/cfb/players/anthony-becht-1.html',
#  'https://www.sports-reference.com/cfb/players/anthony-boone-1.html',
#  'https://www.sports-reference.com/cfb/players/anthony-brown-6.html',
#  'https://www.sports-reference.com/cfb/players/anthony-cantele-1.html',
#  'https://www.sports-reference.com/cfb/players/anthony-chickillo-1.html',
#  'https://www.sports-reference.com/cfb/players/anthony-davis-2.html',
#  'https://www.sports-reference.com/cfb/players/anthony-davis-3.html',
#  'https://www.sports-reference.com/cfb/players/anthony-dixon-1.html',
#  'https://www.sports-reference.com/cfb/players/anthony-fasano-1.html',
#  'https://www.sports-reference.com/cfb/players/anthony-felder-1.html',
#  'https://www.sports-reference.com/cfb/players/anthony-fera-1.html',
#  'https://www.sports-reference.com/cfb/players/anthony-floyd-1.html',
#  'https://www.sports-reference.com/cfb/players/anthony-gonzalez-1.html',
#  'https://www.sports-reference.com/cfb/players/anthony-gordon-2.html',
#  'https://www.sports-reference.com/cfb/players/anthony-harris-4.html',
#  'https://www.sports-reference.com/cfb/players/anthony-henry-1.html',
#  'https://www.sports-reference.com/cfb/players/anthony-hill-1.html',
#  'https://www.sports-reference.com/cfb/players/anthony-hitchens-1.html',
#  'https://www.sports-reference.com/cfb/players/anthony-jefferson-1.html',
#  'https://www.sports-reference.com/cfb/players/anthony-johnson-13.html',
#  'https://www.sports-reference.com/cfb/players/anthony-johnson-7.html',
#  'https://www.sports-reference.com/cfb/players/anthony-kimble-1.html',
#  'https://www.sports-reference.com/cfb/players/anthony-malbrough-1.html',
#  'https://www.sports-reference.com/cfb/players/anthony-mccoy-1.html',
#  'https://www.sports-reference.com/cfb/players/anthony-mcfarland-2.html',
#  'https://www.sports-reference.com/cfb/players/anthony-miller-6.html',
#  'https://www.sports-reference.com/cfb/players/anthony-mix-1.html',
#  'https://www.sports-reference.com/cfb/players/anthony-morelli-1.html',
#  'https://www.sports-reference.com/cfb/players/anthony-nelson-1.html',
#  'https://www.sports-reference.com/cfb/players/anthony-parker-2.html',
#  'https://www.sports-reference.com/cfb/players/anthony-pudewell-1.html',
#  'https://www.sports-reference.com/cfb/players/anthony-schlegel-2.html',
#  'https://www.sports-reference.com/cfb/players/anthony-sherman-1.html',
#  'https://www.sports-reference.com/cfb/players/anthony-smith-1.html',
#  'https://www.sports-reference.com/cfb/players/anthony-spencer-1.html',
#  'https://www.sports-reference.com/cfb/players/anthony-steen-1.html',
#  'https://www.sports-reference.com/cfb/players/anthony-thomas-2.html',
#  'https://www.sports-reference.com/cfb/players/anthony-trucks-1.html',
#  'https://www.sports-reference.com/cfb/players/anthony-walker-1.html',
#  'https://www.sports-reference.com/cfb/players/anthony-waters-1.html',
#  'https://www.sports-reference.com/cfb/players/anthony-weaver-1.html',
#  'https://www.sports-reference.com/cfb/players/anthony-winbush-1.html',
#  'https://www.sports-reference.com/cfb/players/anthony-zettel-1.html',
#  'https://www.sports-reference.com/cfb/players/antoine-brooks-1.html',
#  'https://www.sports-reference.com/cfb/players/antoine-caldwell-1.html',
#  'https://www.sports-reference.com/cfb/players/antoine-cason-1.html',
#  'https://www.sports-reference.com/cfb/players/antoine-harris-1.html',
#  'https://www.sports-reference.com/cfb/players/antoine-wesley-1.html',
#  'https://www.sports-reference.com/cfb/players/antoine-winfield-jr-1.html',
#  'https://www.sports-reference.com/cfb/players/antone-exum-1.html',
#  'https://www.sports-reference.com/cfb/players/antonio-allen-1.html',
#  'https://www.sports-reference.com/cfb/players/antonio-andrews-1.html',
#  'https://www.sports-reference.com/cfb/players/antonio-brown-1.html',
#  'https://www.sports-reference.com/cfb/players/antonio-bryant-1.html',
#  'https://www.sports-reference.com/cfb/players/antonio-callaway-1.html',
#  'https://www.sports-reference.com/cfb/players/antonio-coleman-1.html',
#  'https://www.sports-reference.com/cfb/players/antonio-cromartie-1.html',
#  'https://www.sports-reference.com/cfb/players/antonio-fenelus-1.html',
#  'https://www.sports-reference.com/cfb/players/antonio-gandy-golden-1.html',
#  'https://www.sports-reference.com/cfb/players/antonio-garay-1.html',
#  'https://www.sports-reference.com/cfb/players/antonio-garcia-1.html',
#  'https://www.sports-reference.com/cfb/players/antonio-gibson-2.html',
#  'https://www.sports-reference.com/cfb/players/antonio-johnson-3.html',
#  'https://www.sports-reference.com/cfb/players/antonio-malone-1.html',
#  'https://www.sports-reference.com/cfb/players/antonio-morrison-1.html',
#  'https://www.sports-reference.com/cfb/players/antonio-perkins-1.html',
#  'https://www.sports-reference.com/cfb/players/antonio-pittman-1.html',
#  'https://www.sports-reference.com/cfb/players/antrel-rolle-1.html',
#  'https://www.sports-reference.com/cfb/players/anttaj-hawthorne-1.html',
#  'https://www.sports-reference.com/cfb/players/antwaan-randle-el-1.html',
#  'https://www.sports-reference.com/cfb/players/antwan-applewhite-1.html',
#  'https://www.sports-reference.com/cfb/players/antwan-barnes-1.html',
#  'https://www.sports-reference.com/cfb/players/antwan-goodley-1.html',
#  'https://www.sports-reference.com/cfb/players/antwan-peek-1.html',
#  'https://www.sports-reference.com/cfb/players/antwaun-woods-1.html',
#  'https://www.sports-reference.com/cfb/players/antwoine-sanders-1.html',
#  'https://www.sports-reference.com/cfb/players/antwone-savage-1.html',
#  'https://www.sports-reference.com/cfb/players/antwuan-reed-1.html',
#  'https://www.sports-reference.com/cfb/players/anwar-phillips-1.html',
#  'https://www.sports-reference.com/cfb/players/aq-shipley-1.html',
#  'https://www.sports-reference.com/cfb/players/aqib-talib-1.html',
#  'https://www.sports-reference.com/cfb/players/ardarius-stewart-1.html',
#  'https://www.sports-reference.com/cfb/players/arden-key-1.html',
#  'https://www.sports-reference.com/cfb/players/arian-foster-1.html',
#  'https://www.sports-reference.com/cfb/players/aric-morris-1.html',
#  'https://www.sports-reference.com/cfb/players/aric-williams-1.html',
#  'https://www.sports-reference.com/cfb/players/arie-kouandjio-1.html',
#  'https://www.sports-reference.com/cfb/players/arik-armstead-1.html',
#  'https://www.sports-reference.com/cfb/players/armando-allen-1.html',
#  'https://www.sports-reference.com/cfb/players/armani-watts-1.html',
#  'https://www.sports-reference.com/cfb/players/armon-binns-1.html',
#  'https://www.sports-reference.com/cfb/players/armon-watts-1.html',
#  'https://www.sports-reference.com/cfb/players/arnaz-battle-1.html',
#  'https://www.sports-reference.com/cfb/players/arnold-jackson-1.html',
#  'https://www.sports-reference.com/cfb/players/arnold-parker-1.html',
#  'https://www.sports-reference.com/cfb/players/arrelious-benn-1.html',
#  'https://www.sports-reference.com/cfb/players/arron-sears-1.html',
#  'https://www.sports-reference.com/cfb/players/arryn-siposs-1.html',
#  'https://www.sports-reference.com/cfb/players/art-carmody-1.html',
#  'https://www.sports-reference.com/cfb/players/artavis-scott-1.html',
#  'https://www.sports-reference.com/cfb/players/arthur-brown-1.html',
#  'https://www.sports-reference.com/cfb/players/arthur-jones-1.html',
#  'https://www.sports-reference.com/cfb/players/arthur-lynch-1.html',
#  'https://www.sports-reference.com/cfb/players/arthur-maulet-1.html',
#  'https://www.sports-reference.com/cfb/players/artie-burns-1.html',
#  'https://www.sports-reference.com/cfb/players/artose-pinner-1.html',
#  'https://www.sports-reference.com/cfb/players/asante-samuel-1.html',
#  'https://www.sports-reference.com/cfb/players/ashawn-robinson-1.html',
#  'https://www.sports-reference.com/cfb/players/asher-allen-1.html',
#  'https://www.sports-reference.com/cfb/players/ashley-lelie-1.html',
#  'https://www.sports-reference.com/cfb/players/ashton-lampkin-1.html',
#  'https://www.sports-reference.com/cfb/players/ashton-youboty-1.html',
#  'https://www.sports-reference.com/cfb/players/ashtyn-davis-1.html',
#  'https://www.sports-reference.com/cfb/players/atari-bigby-1.html',
#  'https://www.sports-reference.com/cfb/players/atrews-bell-1.html',
#  'https://www.sports-reference.com/cfb/players/auden-tate-1.html',
#  'https://www.sports-reference.com/cfb/players/audie-cole-1.html',
#  'https://www.sports-reference.com/cfb/players/augustus-parrish-1.html',
#  'https://www.sports-reference.com/cfb/players/aundrae-allison-1.html',
#  'https://www.sports-reference.com/cfb/players/austin-allen-1.html',
#  'https://www.sports-reference.com/cfb/players/austin-blythe-1.html',
#  'https://www.sports-reference.com/cfb/players/austin-bryant-1.html',
#  'https://www.sports-reference.com/cfb/players/austin-collie-1.html',
#  'https://www.sports-reference.com/cfb/players/austin-corbett-2.html',
#  'https://www.sports-reference.com/cfb/players/austin-davis-1.html',
#  'https://www.sports-reference.com/cfb/players/austin-franklin-1.html',
#  'https://www.sports-reference.com/cfb/players/austin-hooper-1.html',
#  'https://www.sports-reference.com/cfb/players/austin-jackson-2.html',
#  'https://www.sports-reference.com/cfb/players/austin-johnson-2.html',
#  'https://www.sports-reference.com/cfb/players/austin-mack-1.html',
#  'https://www.sports-reference.com/cfb/players/austin-pettis-1.html',
#  'https://www.sports-reference.com/cfb/players/austin-rehkow-1.html',
#  'https://www.sports-reference.com/cfb/players/austin-seferian-jenkins-1.html',
#  'https://www.sports-reference.com/cfb/players/austin-seibert-1.html',
#  'https://www.sports-reference.com/cfb/players/austin-shepherd-1.html',
#  'https://www.sports-reference.com/cfb/players/austin-wheatley-1.html',
#  'https://www.sports-reference.com/cfb/players/avery-gennesy-1.html',
#  'https://www.sports-reference.com/cfb/players/avery-williamson-1.html',
#  'https://www.sports-reference.com/cfb/players/avery-young-1.html',
#  'https://www.sports-reference.com/cfb/players/aviante-collins-1.html',
#  'https://www.sports-reference.com/cfb/players/avon-cobourne-1.html',
#  'https://www.sports-reference.com/cfb/players/avonte-maddox-1.html',
#  'https://www.sports-reference.com/cfb/players/azeem-victor-1.html',
#  'https://www.sports-reference.com/cfb/players/azeez-al-shaair-1.html',
#  'https://www.sports-reference.com/cfb/players/azur-kamara-1.html',
#  'https://www.sports-reference.com/cfb/players/bacarri-rambo-1.html',
#  'https://www.sports-reference.com/cfb/players/baker-mayfield-1.html',
#  'https://www.sports-reference.com/cfb/players/baraka-atkins-1.html',
#  'https://www.sports-reference.com/cfb/players/barkevious-mingo-1.html',
#  'https://www.sports-reference.com/cfb/players/barrett-green-1.html',
#  'https://www.sports-reference.com/cfb/players/barrett-jones-1.html',
#  'https://www.sports-reference.com/cfb/players/barrett-ruud-1.html',
#  'https://www.sports-reference.com/cfb/players/barry-booker-1.html',
#  'https://www.sports-reference.com/cfb/players/barry-church-1.html',
#  'https://www.sports-reference.com/cfb/players/barry-cofield-1.html',
#  'https://www.sports-reference.com/cfb/players/bashaud-breeland-1.html',
#  'https://www.sports-reference.com/cfb/players/bashir-yamini-1.html',
#  'https://www.sports-reference.com/cfb/players/bear-pascoe-1.html',
#  'https://www.sports-reference.com/cfb/players/beau-bell-1.html',
#  'https://www.sports-reference.com/cfb/players/beau-benzschawel-1.html',
#  'https://www.sports-reference.com/cfb/players/beau-reliford-1.html',
#  'https://www.sports-reference.com/cfb/players/ben-banogu-1.html',
#  'https://www.sports-reference.com/cfb/players/ben-boulware-1.html',
#  'https://www.sports-reference.com/cfb/players/ben-braden-1.html',
#  'https://www.sports-reference.com/cfb/players/ben-bredeson-1.html',
#  'https://www.sports-reference.com/cfb/players/ben-burr-kirven-1.html',
#  'https://www.sports-reference.com/cfb/players/ben-emanuel-1.html',
#  'https://www.sports-reference.com/cfb/players/ben-gedeon-1.html',
#  'https://www.sports-reference.com/cfb/players/ben-grubbs-1.html',
#  'https://www.sports-reference.com/cfb/players/ben-hamilton-1.html',
#  'https://www.sports-reference.com/cfb/players/ben-hartsock-1.html',
#  'https://www.sports-reference.com/cfb/players/ben-heeney-1.html',
#  'https://www.sports-reference.com/cfb/players/ben-jones-3.html',
#  'https://www.sports-reference.com/cfb/players/ben-kelly-1.html',
#  'https://www.sports-reference.com/cfb/players/ben-koyack-1.html',
#  'https://www.sports-reference.com/cfb/players/ben-leber-1.html',
#  'https://www.sports-reference.com/cfb/players/ben-lemay-1.html',
#  'https://www.sports-reference.com/cfb/players/ben-moffitt-1.html',
#  'https://www.sports-reference.com/cfb/players/ben-obomanu-1.html',
#  'https://www.sports-reference.com/cfb/players/ben-patrick-1.html',
#  'https://www.sports-reference.com/cfb/players/ben-powers-1.html',
#  'https://www.sports-reference.com/cfb/players/ben-roethlisberger-1.html',
#  'https://www.sports-reference.com/cfb/players/ben-tate-1.html',
#  'https://www.sports-reference.com/cfb/players/ben-taylor-1.html',
#  'https://www.sports-reference.com/cfb/players/ben-troupe-1.html',
#  'https://www.sports-reference.com/cfb/players/ben-utecht-1.html',
#  'https://www.sports-reference.com/cfb/players/ben-wilkerson-1.html',
#  'https://www.sports-reference.com/cfb/players/benardrick-mckinney-1.html',
#  'https://www.sports-reference.com/cfb/players/bene-benwikere-1.html',
#  'https://www.sports-reference.com/cfb/players/beniquez-brown-1.html',
#  'https://www.sports-reference.com/cfb/players/benito-jones-1.html',
#  'https://www.sports-reference.com/cfb/players/benjamin-snell-jr-1.html',
#  'https://www.sports-reference.com/cfb/players/benjamin-watson-1.html',
#  'https://www.sports-reference.com/cfb/players/benjarvus-green-ellis-1.html',
#  'https://www.sports-reference.com/cfb/players/bennett-jackson-1.html',
#  'https://www.sports-reference.com/cfb/players/bennie-fowler-1.html',
#  'https://www.sports-reference.com/cfb/players/bennie-joppru-1.html',
#  'https://www.sports-reference.com/cfb/players/bennie-logan-1.html',
#  'https://www.sports-reference.com/cfb/players/bernard-berrian-1.html',
#  'https://www.sports-reference.com/cfb/players/bernard-morris-1.html',
#  'https://www.sports-reference.com/cfb/players/bernard-pierce-1.html',
#  'https://www.sports-reference.com/cfb/players/bernard-pollard-1.html',
#  'https://www.sports-reference.com/cfb/players/bethel-johnson-1.html',
#  'https://www.sports-reference.com/cfb/players/bhawoh-jue-1.html',
#  'https://www.sports-reference.com/cfb/players/bilal-powell-1.html',
#  'https://www.sports-reference.com/cfb/players/bill-swancutt-1.html',
#  'https://www.sports-reference.com/cfb/players/billy-baber-1.html',
#  'https://www.sports-reference.com/cfb/players/billy-bajema-1.html',
#  'https://www.sports-reference.com/cfb/players/billy-mcmullen-1.html',
#  'https://www.sports-reference.com/cfb/players/billy-pittman-1.html',
#  'https://www.sports-reference.com/cfb/players/billy-price-1.html',
#  'https://www.sports-reference.com/cfb/players/billy-silva-1.html',
#  'https://www.sports-reference.com/cfb/players/billy-strother-1.html',
#  'https://www.sports-reference.com/cfb/players/billy-winn-1.html',
#  'https://www.sports-reference.com/cfb/players/binjimen-victor-1.html',
#  'https://www.sports-reference.com/cfb/players/bishop-sankey-1.html',
#  'https://www.sports-reference.com/cfb/players/bj-askew-1.html',
#  'https://www.sports-reference.com/cfb/players/bj-catalon-1.html',
#  'https://www.sports-reference.com/cfb/players/bj-cunningham-1.html',
#  'https://www.sports-reference.com/cfb/players/bj-dubose-1.html',
#  'https://www.sports-reference.com/cfb/players/bj-goodson-1.html',
#  'https://www.sports-reference.com/cfb/players/bj-hill-3.html',
#  'https://www.sports-reference.com/cfb/players/bj-johnson-1.html',
#  'https://www.sports-reference.com/cfb/players/bj-raji-1.html',
#  'https://www.sports-reference.com/cfb/players/bj-sander-1.html',
#  'https://www.sports-reference.com/cfb/players/bj-symons-1.html',
#  'https://www.sports-reference.com/cfb/players/bj-tucker-1.html',
#  'https://www.sports-reference.com/cfb/players/bjoern-werner-1.html',
#  'https://www.sports-reference.com/cfb/players/blace-brown-1.html',
#  'https://www.sports-reference.com/cfb/players/blaine-gabbert-1.html',
#  'https://www.sports-reference.com/cfb/players/blair-brown-1.html',
#  'https://www.sports-reference.com/cfb/players/blair-phillips-1.html',
#  'https://www.sports-reference.com/cfb/players/blair-walsh-1.html',
#  'https://www.sports-reference.com/cfb/players/blair-white-1.html',
#  'https://www.sports-reference.com/cfb/players/blake-bell-1.html',
#  'https://www.sports-reference.com/cfb/players/blake-bortles-1.html',
#  'https://www.sports-reference.com/cfb/players/blake-cashman-1.html',
#  'https://www.sports-reference.com/cfb/players/blake-ferguson-3.html',
#  'https://www.sports-reference.com/cfb/players/blake-martinez-1.html',
#  'https://www.sports-reference.com/cfb/players/blake-sims-2.html',
#  'https://www.sports-reference.com/cfb/players/blessuan-austin-1.html',
#  'https://www.sports-reference.com/cfb/players/blidi-wreh-wilson-1.html',
#  'https://www.sports-reference.com/cfb/players/bo-scaife-1.html',
#  'https://www.sports-reference.com/cfb/players/bo-scarbrough-1.html',
#  'https://www.sports-reference.com/cfb/players/bob-sanders-1.html',
#  'https://www.sports-reference.com/cfb/players/bobby-blizzard-1.html',
#  'https://www.sports-reference.com/cfb/players/bobby-carpenter-1.html',
#  'https://www.sports-reference.com/cfb/players/bobby-cowan-1.html',
#  'https://www.sports-reference.com/cfb/players/bobby-evans-1.html',
#  'https://www.sports-reference.com/cfb/players/bobby-gray-1.html',
#  'https://www.sports-reference.com/cfb/players/bobby-hart-2.html',
#  'https://www.sports-reference.com/cfb/players/bobby-jackson-1.html',
#  'https://www.sports-reference.com/cfb/players/bobby-massie-1.html',
#  'https://www.sports-reference.com/cfb/players/bobby-mccain-1.html',
#  'https://www.sports-reference.com/cfb/players/bobby-newcombe-1.html',
#  'https://www.sports-reference.com/cfb/players/bobby-okereke-1.html',
#  'https://www.sports-reference.com/cfb/players/bobby-purify-1.html',
#  'https://www.sports-reference.com/cfb/players/bobby-richardson-1.html',
#  'https://www.sports-reference.com/cfb/players/bobby-wade-1.html',
#  'https://www.sports-reference.com/cfb/players/boo-williams-1.html',
#  'https://www.sports-reference.com/cfb/players/boone-stutz-1.html',
#  'https://www.sports-reference.com/cfb/players/boris-lee-1.html',
#  'https://www.sports-reference.com/cfb/players/boseko-lokombo-1.html',
#  'https://www.sports-reference.com/cfb/players/boss-bailey-1.html',
#  'https://www.sports-reference.com/cfb/players/brad-banks-1.html',
#  'https://www.sports-reference.com/cfb/players/brad-butler-1.html',
#  'https://www.sports-reference.com/cfb/players/brad-cottam-1.html',
#  'https://www.sports-reference.com/cfb/players/brad-craddock-1.html',
#  'https://www.sports-reference.com/cfb/players/brad-kaaya-1.html',
#  'https://www.sports-reference.com/cfb/players/brad-nortman-1.html',
#  'https://www.sports-reference.com/cfb/players/brad-smith-1.html',
#  'https://www.sports-reference.com/cfb/players/brad-wing-1.html',
#  'https://www.sports-reference.com/cfb/players/braden-brown-1.html',
#  'https://www.sports-reference.com/cfb/players/braden-mann-1.html',
#  'https://www.sports-reference.com/cfb/players/braden-smith-2.html',
#  'https://www.sports-reference.com/cfb/players/braden-wilson-1.html',
#  'https://www.sports-reference.com/cfb/players/bradie-ewing-1.html',
#  'https://www.sports-reference.com/cfb/players/bradie-james-1.html',
#  'https://www.sports-reference.com/cfb/players/bradlee-anae-1.html',
#  'https://www.sports-reference.com/cfb/players/bradlee-van-pelt-1.html',
#  'https://www.sports-reference.com/cfb/players/bradley-chubb-1.html',
#  'https://www.sports-reference.com/cfb/players/bradley-fletcher-1.html',
#  'https://www.sports-reference.com/cfb/players/bradley-jennings-1.html',
#  'https://www.sports-reference.com/cfb/players/bradley-northnagel-1.html',
#  'https://www.sports-reference.com/cfb/players/bradley-pinion-1.html',
#  'https://www.sports-reference.com/cfb/players/bradley-roby-1.html',
#  'https://www.sports-reference.com/cfb/players/brady-poppinga-1.html',
#  'https://www.sports-reference.com/cfb/players/brady-quinn-1.html',
#  'https://www.sports-reference.com/cfb/players/bralon-addison-1.html',
#  'https://www.sports-reference.com/cfb/players/branden-albert-1.html',
#  'https://www.sports-reference.com/cfb/players/branden-jackson-1.html',
#  'https://www.sports-reference.com/cfb/players/brandin-cooks-1.html',
#  'https://www.sports-reference.com/cfb/players/brandon-aiyuk-1.html',
#  'https://www.sports-reference.com/cfb/players/brandon-allen-2.html',
#  'https://www.sports-reference.com/cfb/players/brandon-bair-1.html',
#  'https://www.sports-reference.com/cfb/players/brandon-banks-1.html',
#  'https://www.sports-reference.com/cfb/players/brandon-bolden-1.html',
#  'https://www.sports-reference.com/cfb/players/brandon-boykin-1.html',
#  'https://www.sports-reference.com/cfb/players/brandon-breazell-1.html',
#  'https://www.sports-reference.com/cfb/players/brandon-bridge-1.html',
#  'https://www.sports-reference.com/cfb/players/brandon-burton-1.html',
#  'https://www.sports-reference.com/cfb/players/brandon-carter-1.html',
#  'https://www.sports-reference.com/cfb/players/brandon-chillar-1.html',
#  'https://www.sports-reference.com/cfb/players/brandon-coleman-2.html',
#  'https://www.sports-reference.com/cfb/players/brandon-deaderick-1.html',
#  'https://www.sports-reference.com/cfb/players/brandon-doman-1.html',
#  'https://www.sports-reference.com/cfb/players/brandon-doughty-1.html',
#  'https://www.sports-reference.com/cfb/players/brandon-drumm-1.html',
#  'https://www.sports-reference.com/cfb/players/brandon-everage-1.html',
#  'https://www.sports-reference.com/cfb/players/brandon-facyson-1.html',
#  'https://www.sports-reference.com/cfb/players/brandon-fields-1.html',
#  'https://www.sports-reference.com/cfb/players/brandon-flowers-1.html',
#  'https://www.sports-reference.com/cfb/players/brandon-ghee-1.html',
#  'https://www.sports-reference.com/cfb/players/brandon-gibson-1.html',
#  'https://www.sports-reference.com/cfb/players/brandon-graham-1.html',
#  'https://www.sports-reference.com/cfb/players/brandon-green-2.html',
#  'https://www.sports-reference.com/cfb/players/brandon-harris-1.html',
#  'https://www.sports-reference.com/cfb/players/brandon-harrison-2.html',
#  'https://www.sports-reference.com/cfb/players/brandon-hogan-1.html',
#  'https://www.sports-reference.com/cfb/players/brandon-hughes-1.html',
#  'https://www.sports-reference.com/cfb/players/brandon-jackson-2.html',
#  'https://www.sports-reference.com/cfb/players/brandon-james-1.html',
#  'https://www.sports-reference.com/cfb/players/brandon-jenkins-2.html',
#  'https://www.sports-reference.com/cfb/players/brandon-johnson-1.html',
#  'https://www.sports-reference.com/cfb/players/brandon-jones-13.html',
#  'https://www.sports-reference.com/cfb/players/brandon-jones-3.html',
#  'https://www.sports-reference.com/cfb/players/brandon-knight-2.html',
#  'https://www.sports-reference.com/cfb/players/brandon-lafell-1.html',
#  'https://www.sports-reference.com/cfb/players/brandon-lang-1.html',
#  'https://www.sports-reference.com/cfb/players/brandon-linder-1.html',
#  'https://www.sports-reference.com/cfb/players/brandon-lindsey-1.html',
#  'https://www.sports-reference.com/cfb/players/brandon-lloyd-1.html',
#  'https://www.sports-reference.com/cfb/players/brandon-magee-1.html',
#  'https://www.sports-reference.com/cfb/players/brandon-manumaleuna-1.html',
#  'https://www.sports-reference.com/cfb/players/brandon-marshall-1.html',
#  'https://www.sports-reference.com/cfb/players/brandon-marshall-3.html',
#  'https://www.sports-reference.com/cfb/players/brandon-mcdonald-1.html',
#  'https://www.sports-reference.com/cfb/players/brandon-mcgee-1.html',
#  'https://www.sports-reference.com/cfb/players/brandon-mebane-1.html',
#  'https://www.sports-reference.com/cfb/players/brandon-meriweather-1.html',
#  'https://www.sports-reference.com/cfb/players/brandon-minor-1.html',
#  'https://www.sports-reference.com/cfb/players/brandon-mosley-2.html',
#  'https://www.sports-reference.com/cfb/players/brandon-pace-1.html',
#  'https://www.sports-reference.com/cfb/players/brandon-pettigrew-1.html',
#  'https://www.sports-reference.com/cfb/players/brandon-saine-1.html',
#  'https://www.sports-reference.com/cfb/players/brandon-scherff-1.html',
#  'https://www.sports-reference.com/cfb/players/brandon-sharp-1.html',
#  'https://www.sports-reference.com/cfb/players/brandon-shell-1.html',
#  'https://www.sports-reference.com/cfb/players/brandon-short-1.html',
#  'https://www.sports-reference.com/cfb/players/brandon-siler-1.html',
#  'https://www.sports-reference.com/cfb/players/brandon-spikes-1.html',
#  'https://www.sports-reference.com/cfb/players/brandon-sumrall-1.html',
#  'https://www.sports-reference.com/cfb/players/brandon-tate-1.html',
#  'https://www.sports-reference.com/cfb/players/brandon-taylor-1.html',
#  'https://www.sports-reference.com/cfb/players/brandon-thomas-3.html',
#  'https://www.sports-reference.com/cfb/players/brandon-thompson-3.html',
#  'https://www.sports-reference.com/cfb/players/brandon-underwood-1.html',
#  'https://www.sports-reference.com/cfb/players/brandon-walker-1.html',
#  'https://www.sports-reference.com/cfb/players/brandon-washington-3.html',
#  'https://www.sports-reference.com/cfb/players/brandon-weeden-1.html',
#  'https://www.sports-reference.com/cfb/players/brandon-wilds-1.html',
#  'https://www.sports-reference.com/cfb/players/brandon-williams-10.html',
#  'https://www.sports-reference.com/cfb/players/brandon-williams-6.html',
#  'https://www.sports-reference.com/cfb/players/brandon-williams-9.html',
#  'https://www.sports-reference.com/cfb/players/brandyn-thompson-1.html',
#  'https://www.sports-reference.com/cfb/players/brannan-southerland-1.html',
#  'https://www.sports-reference.com/cfb/players/braxton-berrios-1.html',
#  'https://www.sports-reference.com/cfb/players/braxton-miller-1.html',
#  'https://www.sports-reference.com/cfb/players/braylon-edwards-1.html',
#  'https://www.sports-reference.com/cfb/players/braylon-heard-1.html',
#  'https://www.sports-reference.com/cfb/players/breeland-speaks-1.html',
#  'https://www.sports-reference.com/cfb/players/brendan-carney-1.html',
#  'https://www.sports-reference.com/cfb/players/brennan-marion-1.html',
#  'https://www.sports-reference.com/cfb/players/brennan-williams-1.html',
#  'https://www.sports-reference.com/cfb/players/breno-giacomini-1.html',
#  'https://www.sports-reference.com/cfb/players/brent-bowden-1.html',
#  'https://www.sports-reference.com/cfb/players/brent-urban-1.html',
#  'https://www.sports-reference.com/cfb/players/breshad-perriman-1.html',
#  'https://www.sports-reference.com/cfb/players/bret-smith-1.html',
#  'https://www.sports-reference.com/cfb/players/brett-basanez-1.html',
#  'https://www.sports-reference.com/cfb/players/brett-boyko-1.html',
#  'https://www.sports-reference.com/cfb/players/brett-helms-1.html',
#  'https://www.sports-reference.com/cfb/players/brett-hundley-1.html',
#  'https://www.sports-reference.com/cfb/players/brett-maher-1.html',
#  'https://www.sports-reference.com/cfb/players/brett-pierce-1.html',
#  'https://www.sports-reference.com/cfb/players/brett-romberg-1.html',
#  'https://www.sports-reference.com/cfb/players/brett-roy-1.html',
#  'https://www.sports-reference.com/cfb/players/brett-rypien-1.html',
#  'https://www.sports-reference.com/cfb/players/brett-swenson-1.html',
#  'https://www.sports-reference.com/cfb/players/brett-toth-1.html',
#  'https://www.sports-reference.com/cfb/players/brian-allen-1.html',
#  'https://www.sports-reference.com/cfb/players/brian-allen-2.html',
#  'https://www.sports-reference.com/cfb/players/brian-allen-6.html',
#  'https://www.sports-reference.com/cfb/players/brian-allen-8.html',
#  'https://www.sports-reference.com/cfb/players/brian-bonner-1.html',
#  'https://www.sports-reference.com/cfb/players/brian-brohm-1.html',
#  'https://www.sports-reference.com/cfb/players/brian-burns-2.html',
#  'https://www.sports-reference.com/cfb/players/brian-calhoun-2.html',
#  'https://www.sports-reference.com/cfb/players/brian-cole-1.html',
#  'https://www.sports-reference.com/cfb/players/brian-cushing-1.html',
#  'https://www.sports-reference.com/cfb/players/brian-hartline-1.html',
#  'https://www.sports-reference.com/cfb/players/brian-herrien-1.html',
#  'https://www.sports-reference.com/cfb/players/brian-hill-4.html',
#  'https://www.sports-reference.com/cfb/players/brian-hoyer-1.html',
#  'https://www.sports-reference.com/cfb/players/brian-iwuh-1.html',
#  'https://www.sports-reference.com/cfb/players/brian-jackson-3.html',
#  'https://www.sports-reference.com/cfb/players/brian-leonard-1.html',
#  'https://www.sports-reference.com/cfb/players/brian-lewerke-1.html',
#  'https://www.sports-reference.com/cfb/players/brian-mance-1.html',
#  'https://www.sports-reference.com/cfb/players/brian-natkin-1.html',
#  'https://www.sports-reference.com/cfb/players/brian-oneill-1.html',
#  'https://www.sports-reference.com/cfb/players/brian-orakpo-1.html',
#  'https://www.sports-reference.com/cfb/players/brian-paysinger-1.html',
#  'https://www.sports-reference.com/cfb/players/brian-poli-dixon-1.html',
#  'https://www.sports-reference.com/cfb/players/brian-price-1.html',
#  'https://www.sports-reference.com/cfb/players/brian-robiskie-1.html',
#  'https://www.sports-reference.com/cfb/players/brian-robison-1.html',
#  'https://www.sports-reference.com/cfb/players/brian-rolle-1.html',
#  'https://www.sports-reference.com/cfb/players/brian-schwenke-1.html',
#  'https://www.sports-reference.com/cfb/players/brian-stahovich-1.html',
#  'https://www.sports-reference.com/cfb/players/brian-urlacher-1.html',
#  'https://www.sports-reference.com/cfb/players/brian-young-1.html',
#  'https://www.sports-reference.com/cfb/players/briean-boddy-calhoun-1.html',
#  'https://www.sports-reference.com/cfb/players/britton-colquitt-1.html',
#  'https://www.sports-reference.com/cfb/players/brock-berlin-1.html',
#  'https://www.sports-reference.com/cfb/players/brock-osweiler-1.html',
#  'https://www.sports-reference.com/cfb/players/brock-vereen-1.html',
#  'https://www.sports-reference.com/cfb/players/brock-williams-1.html',
#  'https://www.sports-reference.com/cfb/players/broderick-washington-1.html',
#  'https://www.sports-reference.com/cfb/players/brodie-croyle-1.html',
#  'https://www.sports-reference.com/cfb/players/brodney-pool-1.html',
#  'https://www.sports-reference.com/cfb/players/brodrick-bunkley-1.html',
#  'https://www.sports-reference.com/cfb/players/brody-eldridge-1.html',
#  'https://www.sports-reference.com/cfb/players/bronson-kaufusi-1.html',
#  'https://www.sports-reference.com/cfb/players/brooks-ellis-1.html',
#  'https://www.sports-reference.com/cfb/players/brooks-foster-1.html',
#  'https://www.sports-reference.com/cfb/players/brooks-reed-1.html',
#  'https://www.sports-reference.com/cfb/players/bruce-branch-1.html',
#  'https://www.sports-reference.com/cfb/players/bruce-campbell-2.html',
#  'https://www.sports-reference.com/cfb/players/bruce-carter-1.html',
#  'https://www.sports-reference.com/cfb/players/bruce-davis-1.html',
# ...
#  'https://www.sports-reference.com/cfb/players/carl-granderson-1.html',
#  'https://www.sports-reference.com/cfb/players/carl-ihenacho-1.html',
#  'https://www.sports-reference.com/cfb/players/carl-lawson-2.html',
#  'https://www.sports-reference.com/cfb/players/carl-nassib-1.html',
#  'https://www.sports-reference.com/cfb/players/carl-nesmith-1.html',
#  'https://www.sports-reference.com/cfb/players/carl-nicks-1.html',
#  'https://www.sports-reference.com/cfb/players/carl-stewart-1.html',
#  'https://www.sports-reference.com/cfb/players/carlos-davis-3.html',
#  'https://www.sports-reference.com/cfb/players/carlos-dunlap-1.html',
#  'https://www.sports-reference.com/cfb/players/carlos-francis-1.html',
#  'https://www.sports-reference.com/cfb/players/carlos-hall-1.html',
#  'https://www.sports-reference.com/cfb/players/carlos-henderson-1.html',
#  'https://www.sports-reference.com/cfb/players/carlos-hyde-1.html',
#  'https://www.sports-reference.com/cfb/players/carlos-perez-1.html',
#  'https://www.sports-reference.com/cfb/players/carlos-polk-1.html',
#  'https://www.sports-reference.com/cfb/players/carlos-rogers-1.html',
#  'https://www.sports-reference.com/cfb/players/carlos-watkins-1.html',
#  'https://www.sports-reference.com/cfb/players/carlton-davis-1.html',
#  'https://www.sports-reference.com/cfb/players/carlton-mitchell-1.html',
#  'https://www.sports-reference.com/cfb/players/carlton-powell-1.html',
#  'https://www.sports-reference.com/cfb/players/carnell-williams-1.html',
#  'https://www.sports-reference.com/cfb/players/carroll-phillips-1.html',
#  'https://www.sports-reference.com/cfb/players/carson-palmer-1.html',
#  'https://www.sports-reference.com/cfb/players/carson-wiggs-1.html',
#  'https://www.sports-reference.com/cfb/players/carter-coughlin-1.html',
#  'https://www.sports-reference.com/cfb/players/cary-harris-1.html',
#  'https://www.sports-reference.com/cfb/players/case-keenum-1.html',
#  'https://www.sports-reference.com/cfb/players/casey-clausen-1.html',
#  'https://www.sports-reference.com/cfb/players/casey-crawford-1.html',
#  'https://www.sports-reference.com/cfb/players/casey-hampton-1.html',
#  'https://www.sports-reference.com/cfb/players/casey-hayward-1.html',
#  'https://www.sports-reference.com/cfb/players/casey-matthews-1.html',
#  'https://www.sports-reference.com/cfb/players/casey-moore-1.html',
#  'https://www.sports-reference.com/cfb/players/casey-roussel-1.html',
#  'https://www.sports-reference.com/cfb/players/casey-toohill-1.html',
#  'https://www.sports-reference.com/cfb/players/cassanova-mckinzy-1.html',
#  'https://www.sports-reference.com/cfb/players/cassius-marsh-1.html',
#  'https://www.sports-reference.com/cfb/players/cato-june-1.html',
#  'https://www.sports-reference.com/cfb/players/cayleb-jones-2.html',
#  'https://www.sports-reference.com/cfb/players/cece-jefferson-1.html',
#  'https://www.sports-reference.com/cfb/players/cecil-sapp-1.html',
#  'https://www.sports-reference.com/cfb/players/cedric-benson-1.html',
#  'https://www.sports-reference.com/cfb/players/cedric-cobbs-1.html',
#  'https://www.sports-reference.com/cfb/players/cedric-griffin-1.html',
#  'https://www.sports-reference.com/cfb/players/cedric-hilliard-1.html',
#  'https://www.sports-reference.com/cfb/players/cedric-houston-1.html',
#  'https://www.sports-reference.com/cfb/players/cedric-humes-1.html',
#  'https://www.sports-reference.com/cfb/players/cedric-james-1.html',
#  'https://www.sports-reference.com/cfb/players/cedric-ogbuehi-1.html',
#  'https://www.sports-reference.com/cfb/players/cedric-peerman-1.html',
#  'https://www.sports-reference.com/cfb/players/cedric-reed-1.html',
#  'https://www.sports-reference.com/cfb/players/cedric-scott-1.html',
#  'https://www.sports-reference.com/cfb/players/cedric-wilson-3.html',
#  'https://www.sports-reference.com/cfb/players/cedrick-wilson-1.html',
#  'https://www.sports-reference.com/cfb/players/ceedee-lamb-1.html',
#  'https://www.sports-reference.com/cfb/players/cesar-ruiz-1.html',
#  'https://www.sports-reference.com/cfb/players/cethan-carter-1.html',
#  'https://www.sports-reference.com/cfb/players/chad-beasley-1.html',
#  'https://www.sports-reference.com/cfb/players/chad-greenway-1.html',
#  'https://www.sports-reference.com/cfb/players/chad-hansen-1.html',
#  'https://www.sports-reference.com/cfb/players/chad-henne-1.html',
#  'https://www.sports-reference.com/cfb/players/chad-jackson-1.html',
#  'https://www.sports-reference.com/cfb/players/chad-johnson-1.html',
#  'https://www.sports-reference.com/cfb/players/chad-jones-1.html',
#  'https://www.sports-reference.com/cfb/players/chad-lavalais-1.html',
#  'https://www.sports-reference.com/cfb/players/chad-morton-1.html',
#  'https://www.sports-reference.com/cfb/players/chad-owens-1.html',
#  'https://www.sports-reference.com/cfb/players/chad-pennington-1.html',
#  'https://www.sports-reference.com/cfb/players/chad-simpson-1.html',
#  'https://www.sports-reference.com/cfb/players/chad-thomas-1.html',
#  'https://www.sports-reference.com/cfb/players/chad-upshaw-1.html',
#  'https://www.sports-reference.com/cfb/players/chad-wheeler-1.html',
#  'https://www.sports-reference.com/cfb/players/chad-williams-1.html',
#  'https://www.sports-reference.com/cfb/players/chance-warmack-1.html',
#  'https://www.sports-reference.com/cfb/players/chandler-harnish-1.html',
#  'https://www.sports-reference.com/cfb/players/chandler-jones-2.html',
#  'https://www.sports-reference.com/cfb/players/chandler-williams-1.html',
#  'https://www.sports-reference.com/cfb/players/chandon-sullivan-1.html',
#  'https://www.sports-reference.com/cfb/players/channing-crowder-1.html',
#  'https://www.sports-reference.com/cfb/players/channing-stribling-1.html',
#  'https://www.sports-reference.com/cfb/players/chansi-stuckey-1.html',
#  'https://www.sports-reference.com/cfb/players/chapelle-russell-1.html',
#  'https://www.sports-reference.com/cfb/players/charles-alexander-2.html',
#  'https://www.sports-reference.com/cfb/players/charles-bennett-1.html',
#  'https://www.sports-reference.com/cfb/players/charles-brown-1.html',
#  'https://www.sports-reference.com/cfb/players/charles-brown-6.html',
#  'https://www.sports-reference.com/cfb/players/charles-clay-1.html',
#  'https://www.sports-reference.com/cfb/players/charles-davis-1.html',
#  'https://www.sports-reference.com/cfb/players/charles-drake-1.html',
#  'https://www.sports-reference.com/cfb/players/charles-frederick-1.html',
#  'https://www.sports-reference.com/cfb/players/charles-gaines-2.html',
#  'https://www.sports-reference.com/cfb/players/charles-godfrey-1.html',
#  'https://www.sports-reference.com/cfb/players/charles-gordon-1.html',
#  'https://www.sports-reference.com/cfb/players/charles-grant-1.html',
#  'https://www.sports-reference.com/cfb/players/charles-harris-4.html',
#  'https://www.sports-reference.com/cfb/players/charles-johnson-1.html',
#  'https://www.sports-reference.com/cfb/players/charles-lee-1.html',
#  'https://www.sports-reference.com/cfb/players/charles-leno-1.html',
#  'https://www.sports-reference.com/cfb/players/charles-mitchell-1.html',
#  'https://www.sports-reference.com/cfb/players/charles-omenihu-1.html',
#  'https://www.sports-reference.com/cfb/players/charles-rogers-1.html',
#  'https://www.sports-reference.com/cfb/players/charles-scott-1.html',
#  'https://www.sports-reference.com/cfb/players/charles-sims-2.html',
#  'https://www.sports-reference.com/cfb/players/charles-stackhouse-1.html',
#  'https://www.sports-reference.com/cfb/players/charles-tapper-1.html',
#  'https://www.sports-reference.com/cfb/players/charles-tillman-1.html',
#  'https://www.sports-reference.com/cfb/players/charles-walker-3.html',
#  'https://www.sports-reference.com/cfb/players/charlie-frye-1.html',
#  'https://www.sports-reference.com/cfb/players/charlie-gantt-1.html',
#  'https://www.sports-reference.com/cfb/players/charlie-heck-1.html',
#  'https://www.sports-reference.com/cfb/players/charlie-peprah-1.html',
#  'https://www.sports-reference.com/cfb/players/charlie-whitehurst-1.html',
#  'https://www.sports-reference.com/cfb/players/charlie-woerner-1.html',
#  'https://www.sports-reference.com/cfb/players/charlton-keith-1.html',
#  'https://www.sports-reference.com/cfb/players/charone-peake-1.html',
#  'https://www.sports-reference.com/cfb/players/chas-alecxih-1.html',
#  'https://www.sports-reference.com/cfb/players/chas-henry-1.html',
#  'https://www.sports-reference.com/cfb/players/chase-claypool-1.html',
#  'https://www.sports-reference.com/cfb/players/chase-coffman-1.html',
#  'https://www.sports-reference.com/cfb/players/chase-daniel-1.html',
#  'https://www.sports-reference.com/cfb/players/chase-hansen-1.html',
#  'https://www.sports-reference.com/cfb/players/chase-holbrook-1.html',
#  'https://www.sports-reference.com/cfb/players/chase-litton-1.html',
#  'https://www.sports-reference.com/cfb/players/chase-lyman-1.html',
#  'https://www.sports-reference.com/cfb/players/chase-minnifield-1.html',
#  'https://www.sports-reference.com/cfb/players/chase-ortiz-1.html',
#  'https://www.sports-reference.com/cfb/players/chase-pittman-1.html',
#  'https://www.sports-reference.com/cfb/players/chase-roullier-1.html',
#  'https://www.sports-reference.com/cfb/players/chase-thomas-1.html',
#  'https://www.sports-reference.com/cfb/players/chase-winovich-1.html',
#  'https://www.sports-reference.com/cfb/players/chase-young-1.html',
#  'https://www.sports-reference.com/cfb/players/chastin-west-1.html',
#  'https://www.sports-reference.com/cfb/players/chauncey-davis-1.html',
#  'https://www.sports-reference.com/cfb/players/chauncey-gardner-1.html',
#  'https://www.sports-reference.com/cfb/players/chauncey-rivers-1.html',
#  'https://www.sports-reference.com/cfb/players/chauncey-stovall-1.html',
#  'https://www.sports-reference.com/cfb/players/chauncey-washington-1.html',
#  'https://www.sports-reference.com/cfb/players/chaz-green-1.html',
#  'https://www.sports-reference.com/cfb/players/chaz-powell-1.html',
#  'https://www.sports-reference.com/cfb/players/chaz-williams-1.html',
#  'https://www.sports-reference.com/cfb/players/chester-taylor-1.html',
#  'https://www.sports-reference.com/cfb/players/cheta-ozougwu-1.html',
#  'https://www.sports-reference.com/cfb/players/chevis-jackson-1.html',
#  'https://www.sports-reference.com/cfb/players/chidobe-awuzie-1.html',
#  'https://www.sports-reference.com/cfb/players/chijioke-onyenegecha-1.html',
#  'https://www.sports-reference.com/cfb/players/chimdi-chekwa-1.html',
#  'https://www.sports-reference.com/cfb/players/chinedum-ndukwe-1.html',
#  'https://www.sports-reference.com/cfb/players/chip-vaughn-1.html',
#  'https://www.sports-reference.com/cfb/players/chris-baker-2.html',
#  'https://www.sports-reference.com/cfb/players/chris-borland-1.html',
#  'https://www.sports-reference.com/cfb/players/chris-boswell-1.html',
#  'https://www.sports-reference.com/cfb/players/chris-boyd-1.html',
#  'https://www.sports-reference.com/cfb/players/chris-brown-1.html',
#  'https://www.sports-reference.com/cfb/players/chris-brown-11.html',
#  'https://www.sports-reference.com/cfb/players/chris-brown-4.html',
#  'https://www.sports-reference.com/cfb/players/chris-brown-6.html',
#  'https://www.sports-reference.com/cfb/players/chris-brown-7.html',
#  'https://www.sports-reference.com/cfb/players/chris-carson-1.html',
#  'https://www.sports-reference.com/cfb/players/chris-carter-2.html',
#  'https://www.sports-reference.com/cfb/players/chris-cash-1.html',
#  'https://www.sports-reference.com/cfb/players/chris-chambers-1.html',
#  'https://www.sports-reference.com/cfb/players/chris-chancellor-1.html',
#  'https://www.sports-reference.com/cfb/players/chris-chester-1.html',
#  'https://www.sports-reference.com/cfb/players/chris-clemons-1.html',
#  'https://www.sports-reference.com/cfb/players/chris-cole-2.html',
#  'https://www.sports-reference.com/cfb/players/chris-coleman-1.html',
#  'https://www.sports-reference.com/cfb/players/chris-collins-1.html',
#  'https://www.sports-reference.com/cfb/players/chris-conley-1.html',
#  'https://www.sports-reference.com/cfb/players/chris-conte-1.html',
#  'https://www.sports-reference.com/cfb/players/chris-cook-2.html',
#  'https://www.sports-reference.com/cfb/players/chris-cooley-1.html',
#  'https://www.sports-reference.com/cfb/players/chris-covington-1.html',
#  'https://www.sports-reference.com/cfb/players/chris-culliver-1.html',
#  'https://www.sports-reference.com/cfb/players/chris-davis-2.html',
#  'https://www.sports-reference.com/cfb/players/chris-davis-3.html',
#  'https://www.sports-reference.com/cfb/players/chris-davis-6.html',
#  'https://www.sports-reference.com/cfb/players/chris-denman-1.html',
#  'https://www.sports-reference.com/cfb/players/chris-ellis-1.html',
#  'https://www.sports-reference.com/cfb/players/chris-finke-1.html',
#  'https://www.sports-reference.com/cfb/players/chris-galippo-1.html',
#  'https://www.sports-reference.com/cfb/players/chris-gamble-1.html',
#  'https://www.sports-reference.com/cfb/players/chris-givens-2.html',
#  'https://www.sports-reference.com/cfb/players/chris-godwin-1.html',
#  'https://www.sports-reference.com/cfb/players/chris-gragg-1.html',
#  'https://www.sports-reference.com/cfb/players/chris-hackett-1.html',
#  'https://www.sports-reference.com/cfb/players/chris-hairston-1.html',
#  'https://www.sports-reference.com/cfb/players/chris-hannon-1.html',
#  'https://www.sports-reference.com/cfb/players/chris-harper-2.html',
#  'https://www.sports-reference.com/cfb/players/chris-harrell-1.html',
#  'https://www.sports-reference.com/cfb/players/chris-harrington-1.html',
#  'https://www.sports-reference.com/cfb/players/chris-hawkins-1.html',
#  'https://www.sports-reference.com/cfb/players/chris-hawkins-2.html',
#  'https://www.sports-reference.com/cfb/players/chris-henry-1.html',
#  'https://www.sports-reference.com/cfb/players/chris-henry-3.html',
#  'https://www.sports-reference.com/cfb/players/chris-hope-1.html',
#  'https://www.sports-reference.com/cfb/players/chris-horton-1.html',
#  'https://www.sports-reference.com/cfb/players/chris-houston-1.html',
#  'https://www.sports-reference.com/cfb/players/chris-johnson-1.html',
#  'https://www.sports-reference.com/cfb/players/chris-jones-12.html',
#  'https://www.sports-reference.com/cfb/players/chris-jones-7.html',
#  'https://www.sports-reference.com/cfb/players/chris-jones-8.html',
#  'https://www.sports-reference.com/cfb/players/chris-lacy-2.html',
#  'https://www.sports-reference.com/cfb/players/chris-leak-1.html',
#  'https://www.sports-reference.com/cfb/players/chris-lindstrom-1.html',
#  'https://www.sports-reference.com/cfb/players/chris-long-1.html',
#  'https://www.sports-reference.com/cfb/players/chris-luzar-1.html',
#  'https://www.sports-reference.com/cfb/players/chris-mayes-1.html',
#  'https://www.sports-reference.com/cfb/players/chris-mcgaha-1.html',
#  'https://www.sports-reference.com/cfb/players/chris-mcintosh-1.html',
#  'https://www.sports-reference.com/cfb/players/chris-mckenzie-1.html',
#  'https://www.sports-reference.com/cfb/players/chris-miller-11.html',
#  'https://www.sports-reference.com/cfb/players/chris-moore-4.html',
#  'https://www.sports-reference.com/cfb/players/chris-neild-1.html',
#  'https://www.sports-reference.com/cfb/players/chris-ogbonnaya-1.html',
#  'https://www.sports-reference.com/cfb/players/chris-owusu-1.html',
#  'https://www.sports-reference.com/cfb/players/chris-pantale-1.html',
#  'https://www.sports-reference.com/cfb/players/chris-perry-1.html',
#  'https://www.sports-reference.com/cfb/players/chris-polk-1.html',
#  'https://www.sports-reference.com/cfb/players/chris-rainey-1.html',
#  'https://www.sports-reference.com/cfb/players/chris-redman-1.html',
#  'https://www.sports-reference.com/cfb/players/chris-rix-1.html',
#  'https://www.sports-reference.com/cfb/players/chris-samuels-2.html',
#  'https://www.sports-reference.com/cfb/players/chris-simms-1.html',
#  'https://www.sports-reference.com/cfb/players/chris-slayton-1.html',
#  'https://www.sports-reference.com/cfb/players/chris-smith-14.html',
#  'https://www.sports-reference.com/cfb/players/chris-taylor-2.html',
#  'https://www.sports-reference.com/cfb/players/chris-thompson-1.html',
#  'https://www.sports-reference.com/cfb/players/chris-vance-1.html',
#  'https://www.sports-reference.com/cfb/players/chris-watt-1.html',
#  ...]

# %%
urls = ['https://www.sports-reference.com/cfb/players/sam-darnold-1.html', 
        'https://www.sports-reference.com/cfb/players/denico-autry-1.html', 
        'https://www.sports-reference.com/cfb/players/nick-folk-1.html', 
        'https://www.sports-reference.com/cfb/players/odell-beckham-jr-1.html',
        'https://www.sports-reference.com/cfb/players/adimchinobi-echemandu-1.html']

# %%
college_stats_df = pd.DataFrame(columns=['Link', 'Defense_Games', 'Solo_Tackles', 'Assisted_Tackles', 'Ttl_Tackles', 
                                         'Loss', 'Sacks', 'Defensive_Interceptions', 'Def_Int_Yds', 'Yds_per_Int', 
                                         'Pick_6', 'Defended_Passes', 'Recovered_Fumbles', 'Rec_Fumbles_Yds', 
                                         'Fumbles_Returned_TD', 'Forced_Fumbles', 'Passing_Games', 'Completions', 
                                         'Pass_Attempts', 'Completion_Percent', 'Pass_Yards', 'Pass_Yds_per_Attempt', 
                                         'Adj_Pass_Yds_per_Attempt', 'Pass_TDs', 'Pass_Interceptions', 
                                         'Passer_Rating', 'Rushing/Receiving_Games', 'Rush_Attempts', 'Rush_Yds', 
                                         'Rush_Yds_per_Attempt', 'Rush_TDs', 'Receptions', 'Rec_Yds', 
                                         'Rec_Yds_per_Reception', 'Rec_TDs', 'Plays_from_Scrimmage', 'Scrimmage_Yds', 
                                         'Scrimmage_Yds_per_Attempt', 'Scrimmage_TDs', 'Kicking_Games', 
                                         'XP_Made', 'XP_Attempts', 'XP_Percent', 'FG_Made', 'FG_Attempts', 
                                         'FG_Percent', 'TTL_Kicking_Points', '#Punts', 'Punt_Yds', 'Yds_per_Punt', 
                                         'PuntRet_Games', 'Punt_Returns', 'Punt_Return_Yds', 'Yrds_per_Return', 
                                         'Punt_Returned_for_TD', 'Kickoff_Returns', 'KO_Return_Yds', 
                                         'Yds_per_KO_Return', 'KO_Returned_for_TD', 'Scoring_Games', 'TD_Other', 
                                         'Ttl_TDs', '2PT_Converstions', 'Safety', 'TTL_Points'])

# %%
def get_college_stats(link_list):
    for link in tqdm(link_list):
        url = link
        html_page = requests.get(url) 
        soup = BeautifulSoup(html_page.content, 'html.parser')
        
#         print(url)
        
        # container
        defense = defense_container(soup)
        passing = passing_container(soup)
        rushing = rushing_container(soup)
        scoring = scoring_container(soup)
        kicking = kicking_container(soup)
        punt_ret = punt_ret_container(soup)
        
        # defense 
        # defense games
        try:
            def_games = defense.findAll('td', {'data-stat': 'g'})
            defense_games = def_games[-2].get_text()
#             year1_games = (def_games[0].get_text() if 0 in range(len(def_games)) else 0)
#             print(year1_games)
#             year2_games = (def_games[1].get_text() if 1 in range(len(def_games)) else 0)
#             print(year2_games)
#             year3_games = (def_games[2].get_text() if 2 in range(len(def_games)) else 0)
#             print(year3_games)
#             year4_games = (def_games[3].get_text() if 3 in range(len(def_games)) else 0)
#             ttl_defense_games = ((int(year1_games) if year1_games is not "" else 0) +
#                                  (int(year2_games) if year2_games is not "" else 0) +
#                                  (int(year3_games) if year3_games is not "" else 0) +
#                                  (int(year4_games) if year4_games is not "" else 0))
#             print(ttl_defense_games)
            
        
        except AttributeError:
            defense_games = 0
            ttl_defense_games = 0
        
        # defense solo tackles
        try:
            solotackles = defense.findAll('td', {'data-stat': 'tackles_solo'})
            solotackles = solotackles[-2].get_text()

        except AttributeError:
            solotackles = 0
        
        # defense assisted tackles
        try:
            assistedtackles = defense.findAll('td', {'data-stat': 'tackles_assists'})
            assistedtackles = assistedtackles[-2].get_text()
        
        except AttributeError:
            assistedtackles = 0
            
        # defense tackles_total
        try:
            ttl_tackles = defense.findAll('td', {'data-stat': 'tackles_total'})
            ttl_tackles = ttl_tackles[-2].get_text()
        
        except AttributeError:
            ttl_tackles = 0
            
        # tackles for a loss
        try:
            tackle_loss = defense.findAll('td', {'data-stat': 'tackles_loss'})
            tackle_loss = tackle_loss[-2].get_text()
            
        except AttributeError:
            tackle_loss = 0
            
        # sacks
        try:
            sacks = defense.findAll('td', {'data-stat': 'sacks'})
            sacks = sacks[-2].get_text()
            
        except AttributeError:
            sacks = 0
            
        # defense interception
        try:
            defense_int = defense.findAll('td', {'data-stat': 'def_int'})
            defense_int = defense_int[-2].get_text()
            
        except AttributeError:
            defense_int = 0
            
        # defense interception yards
        try:
            int_yards = defense.findAll('td', {'data-stat': 'def_int_yds'})
            int_yards = int_yards[-2].get_text()
            
        except AttributeError:
            int_yards = 0
            
        # yards per interception
        try:
            yards_per_int = defense.findAll('td', {'data-stat': 'def_int_yds_per_int'})
            yards_per_int = yards_per_int[-2].get_text()
            
        except AttributeError:
            yards_per_int = 0
            
        # pick6
        try:
            pick6 = defense.findAll('td', {'data-stat': 'def_int_td'})
            pick6 = pick6[-2].get_text()
            
        except AttributeError:
            pick6 = 0
            
        # defended passes
        try:
            defended_pass = defense.findAll('td', {'data-stat': 'pass_defended'})
            defended_pass = defended_pass[-2].get_text()
            
        except AttributeError:
            defended_pass = 0
            
        # recovered fumbles
        try:
            recovered_fumbles = defense.findAll('td', {'data-stat': 'fumbles_rec'})
            recovered_fumbles = recovered_fumbles[-2].get_text()
            
        except AttributeError:
            recovered_fumbles = 0
            
        # fumble recovery yards
        try:
            fumble_recover_yrds = defense.findAll('td', {'data-stat': 'fumbles_rec_yds'})
            fumble_recover_yrds = fumble_recover_yrds[-2].get_text()
            
        except AttributeError:
            fumble_recover_yrds = 0

        # fumble recovery for a td
        try:
            recovered_fumbles_td = defense.findAll('td', {'data-stat': 'fumbles_rec_td'})
            recovered_fumbles_td = recovered_fumbles_td[-2].get_text()
            
        except AttributeError:
            recovered_fumbles_td = 0
            
        # forced fumbles
        try:
            forced_fumbles = defense.findAll('td', {'data-stat': 'fumbles_forced'})
            forced_fumbles = forced_fumbles[-2].get_text()
            
        except AttributeError:
            forced_fumbles = 0  
            
        # passing 
        # passing games
        try:
            passing_games = passing.findAll('td', {'data-stat': 'g'})
            passing_games = passing_games[-2].get_text()
            
        except AttributeError:
            passing_games = 0
           
        # completions
        try:
            completions = passing.findAll('td', {'data-stat': 'pass_cmp'})
            completions = completions[-2].get_text()
            
        except AttributeError:
            completions = 0    
            
        # attempts
        try:
            pass_attempts = passing.findAll('td', {'data-stat': 'pass_att'})
            pass_attempts = pass_attempts[-2].get_text()
            
        except AttributeError:
            pass_attempts = 0 
            
        # completion percentage
        try:
            complete_rate = passing.findAll('td', {'data-stat': 'pass_cmp_pct'})
            complete_rate = complete_rate[-2].get_text()
            
        except AttributeError:
            complete_rate = 0 

        # passing yards
        try:
            passing_yards = passing.findAll('td', {'data-stat': 'pass_yds'})
            passing_yards = passing_yards[-2].get_text()
            
        except AttributeError:
            passing_yards = 0 
            
        # yards per attempt
        try:
            yds_per_attempt = passing.findAll('td', {'data-stat': 'pass_yds_per_att'})
            yds_per_attempt = yds_per_attempt[-2].get_text()
            
        except AttributeError:
            yds_per_attempt = 0 
                            
        # adj yards per attempt
        try:
            adj_yds_per_attempt = passing.findAll('td', {'data-stat': 'adj_pass_yds_per_att'})
            adj_yds_per_attempt = adj_yds_per_attempt[-2].get_text()
            
        except AttributeError:
            adj_yds_per_attempt = 0 
        
        # pass tds
        try:
            pass_tds = passing.findAll('td', {'data-stat': 'pass_td'})
            pass_tds = pass_tds[-2].get_text()
            
        except AttributeError:
            pass_tds = 0 
                       
        # pass interceptions
        try:
            pass_ints = passing.findAll('td', {'data-stat': 'pass_int'})
            pass_ints = pass_ints[-2].get_text()
            
        except AttributeError:
            pass_ints = 0  
            
        # passer rating
        try:
            passer_rating = passing.findAll('td', {'data-stat': 'pass_rating'})
            passer_rating = passer_rating[-2].get_text()
            
        except AttributeError:
            passer_rating = 0    

        # Rushing_Receiving games
        try:
            rush_rec_games = rushing.findAll('td', {'data-stat': 'g'})
            rush_rec_games = rush_rec_games[-2].get_text()
            
        except AttributeError:
            rush_rec_games = 0
            
        # rushing attempts
        try:
            rushing_att = rushing.findAll('td', {'data-stat': 'rush_att'})
            rushing_att = rushing_att[-2].get_text()
            
        except AttributeError:
            rushing_att = 0
            
        # rushing yds
        try:
            rushing_yds = rushing.findAll('td', {'data-stat': 'rush_yds'})
            rushing_yds = rushing_yds[-2].get_text()
            
        except AttributeError:
            rushing_yds = 0
        
        # rushing yds per attempt
        try:
            rushing_yds_per_att = rushing.findAll('td', {'data-stat': 'rush_yds_per_att'})
            rushing_yds_per_att = rushing_yds_per_att[-2].get_text()
            
        except AttributeError:
            rushing_yds_per_att = 0
        
        # rushing tds
        try:
            rushing_tds = rushing.findAll('td', {'data-stat': 'rush_td'})
            rushing_tds = rushing_tds[-2].get_text()
            
        except AttributeError:
            rushing_tds = 0
        
        # receptions
        try:
            reception = rushing.findAll('td', {'data-stat': 'rec'})
            reception = reception[-2].get_text()
            
        except AttributeError:
            reception = 0
        
        # reception yds
        try:
            rec_yards = rushing.findAll('td', {'data-stat': 'rec_yds'})
            rec_yards = rec_yards[-2].get_text()
            
        except AttributeError:
            rec_yards = 0
        
        # yds per reception
        try:
            yds_per_reception = rushing.findAll('td', {'data-stat': 'rec_yds_per_rec'})
            yds_per_reception = yds_per_reception[-2].get_text()
            
        except AttributeError:
            yds_per_reception = 0
        
        # td receptions
        try:
            td_receptions = rushing.findAll('td', {'data-stat': 'rec_td'})
            td_receptions = td_receptions[-2].get_text()
            
        except AttributeError:
            td_receptions = 0
        
        # scrimmages
        try:
            scrimmages = rushing.findAll('td', {'data-stat': 'scrim_att'})
            scrimmages = scrimmages[-2].get_text()
            
        except AttributeError:
            scrimmages = 0
        
        # scrimmage yds
        try:
            scrimmage_yds = rushing.findAll('td', {'data-stat': 'scrim_yds'})
            scrimmage_yds = scrimmage_yds[-2].get_text()
            
        except AttributeError:
            scrimmage_yds = 0
        
        # scrimmage yds per attempt
        try:
            scrimmage_yds_per_att = rushing.findAll('td', {'data-stat': 'scrim_yds_per_att'})
            scrimmage_yds_per_att = scrimmage_yds_per_att[-2].get_text()
            
        except AttributeError:
            scrimmage_yds_per_att = 0
        
        # scrimmage tds
        try:
            scrimmage_tds = rushing.findAll('td', {'data-stat': 'scrim_td'})
            scrimmage_tds = scrimmage_tds[-2].get_text()
            
        except AttributeError:
            scrimmage_tds = 0
                
        # kicking games 
        try:
            kick_games = kicking.findAll('td', {'data-stat': 'g'})
            kick_games = kick_games[-2].get_text()
            
        except AttributeError:
            kick_games = 0
            
        # extra points 
        try:
            xp_made = kicking.findAll('td', {'data-stat': 'xpm'})
            xp_made = xp_made[-2].get_text()
            
        except AttributeError:
            xp_made = 0    
            
        # extra point attempts
        try:
            xp_attempt = kicking.findAll('td', {'data-stat': 'xpa'})
            xp_attempt = xp_attempt[-2].get_text()
            
        except AttributeError:
            xp_attempt = 0     
            
        # extra point percentage
        try:
            xp_perc = kicking.findAll('td', {'data-stat': 'xp_pct'})
            xp_perc = xp_perc[-2].get_text()
            
        except AttributeError:
            xp_perc = 0    
        
        # field goals
        try:
            field_goals = kicking.findAll('td', {'data-stat': 'fgm'})
            field_goals = field_goals[-2].get_text()
            
        except AttributeError:
            field_goals = 0 
        
        # field goal attempts
        try:
            field_goals_att = kicking.findAll('td', {'data-stat': 'fga'})
            field_goals_att = field_goals_att[-2].get_text()
            
        except AttributeError:
            field_goals_att = 0 
        
        # field goal percent
        try:
            fg_percent = kicking.findAll('td', {'data-stat': 'fg_pct'})
            fg_percent = fg_percent[-2].get_text()
            
        except AttributeError:
            fg_percent = 0
        
        # ttl kicking points
        try:
            ttl_kick_pts = kicking.findAll('td', {'data-stat': 'kick_points'})
            ttl_kick_pts = ttl_kick_pts[-2].get_text()
            
        except AttributeError:
            ttl_kick_pts = 0
        
        # num punts
        try:
            punts = kicking.findAll('td', {'data-stat': 'punt'})
            punts = punts[-2].get_text()
            
        except AttributeError:
            punts = 0
        
        # punt yards
        try:
            punt_yds = kicking.findAll('td', {'data-stat': 'punt_yds'})
            punt_yds = punt_yds[-2].get_text()
            
        except AttributeError:
            punt_yds = 0
        
        # yards per punt
        try:
            yds_per_punt = kicking.findAll('td', {'data-stat': 'punt_yds_per_punt'})
            yds_per_punt = yds_per_punt[-2].get_text()
            
        except AttributeError:
            yds_per_punt = 0
        
        # punt return games 
        try:
            puntret_games = punt_ret.findAll('td', {'data-stat': 'g'})
            puntret_games = puntret_games[-2].get_text()
        
        except AttributeError:
            puntret_games = 0
        
       # punts returned 
        try:
            ret_punts = punt_ret.findAll('td', {'data-stat': 'punt_ret'})
            ret_punts = ret_punts[-2].get_text()
        
        except AttributeError:
            ret_punts = 0 
        
        # returned yds
        try:
            ret_punts_yds = punt_ret.findAll('td', {'data-stat': 'punt_ret_yds'})
            ret_punts_yds = ret_punts_yds[-2].get_text()
        
        except AttributeError:
            ret_punts_yds = 0
        
        # yds per punt return
        try:
            yds_per_punt_return = punt_ret.findAll('td', {'data-stat': 'punt_ret_yds_per_ret'})
            yds_per_punt_return = yds_per_punt_return[-2].get_text()
        
        except AttributeError:
            yds_per_punt_return = 0
        
        # punt returned for a TD
        try:
            punt_ret_TD = punt_ret.findAll('td', {'data-stat': 'punt_ret_td'})
            punt_ret_TD = punt_ret_TD[-2].get_text()
        
        except AttributeError:
            punt_ret_TD = 0
        
        # kickoff returns
        try:
            kick_returns = punt_ret.findAll('td', {'data-stat': 'kick_ret'})
            kick_returns = kick_returns[-2].get_text()
        
        except AttributeError:
            kick_returns = 0
        
        # kickoff return yds
        try:
            kick_return_yds = punt_ret.findAll('td', {'data-stat': 'kick_ret_yds'})
            kick_return_yds = kick_return_yds[-2].get_text()
        
        except AttributeError:
            kick_return_yds = 0
        
        # yds per kickoff return
        try:
            yds_per_KO_ret = punt_ret.findAll('td', {'data-stat': 'kick_ret_yds_per_ret'})
            yds_per_KO_ret = yds_per_KO_ret[-2].get_text()
        
        except AttributeError:
            yds_per_KO_ret = 0
        
        # kickoff returned for a TD
        try:
            KO_ret_TD = punt_ret.findAll('td', {'data-stat': 'kick_ret_td'})
            KO_ret_TD = KO_ret_TD[-2].get_text()
        
        except AttributeError:
            KO_ret_TD = 0
        
        # scoring games 
        try:
            scoring_games = scoring.findAll('td', {'data-stat': 'g'})
            scoring_games = scoring_games[-2].get_text()
        
        except AttributeError:
            scoring_games = 0
        
        # other TDs scored 
        try:
            other_tds = scoring.findAll('td', {'data-stat': 'td_other'})
            other_tds = other_tds[-2].get_text()
        
        except AttributeError:
            other_tds = 0
        
        # other TDs scored 
        try:
            other_tds = scoring.findAll('td', {'data-stat': 'td_other'})
            other_tds = other_tds[-2].get_text()
        
        except AttributeError:
            other_tds = 0
        
        # ttl TDs scored 
        try:
            total_tds = scoring.findAll('td', {'data-stat': 'td_total'})
            total_tds = total_tds[-2].get_text()
        
        except AttributeError:
            total_tds = 0
       
        # 2 pt conversions 
        try:
            two_pt_conv = scoring.findAll('td', {'data-stat': 'two_pt_md'})
            two_pt_conv = two_pt_conv[-2].get_text()
        
        except AttributeError:
            two_pt_conv = 0
        
        # safety
        try:
            safety = scoring.findAll('td', {'data-stat': 'safety_md'})
            safety = safety[-2].get_text()
        
        except AttributeError:
            safety = 0
        
        # total points scored
        try:
            ttl_pts = scoring.findAll('td', {'data-stat': 'points'})
            ttl_pts = ttl_pts[-2].get_text()
        
        except AttributeError:
            ttl_pts = 0
        
        time.sleep(.5)
        
        global college_stats_df
        college_stats_df = college_stats_df.append({'Link': str(url),
                                                   'Defense_Games': defense_games, 
                                                   'Solo_Tackles': solotackles, 
                                                   'Assisted_Tackles': assistedtackles, 
                                                   'Ttl_Tackles': ttl_tackles, 
                                                   'Loss': tackle_loss, 
                                                   'Sacks': sacks, 
                                                   'Defensive_Interceptions': defense_int, 
                                                   'Def_Int_Yds': int_yards, 
                                                   'Yds_per_Int': yards_per_int, 
                                                   'Pick_6': pick6, 
                                                   'Defended_Passes': defended_pass, 
                                                   'Recovered_Fumbles': recovered_fumbles,
                                                   'Rec_Fumbles_Yds': fumble_recover_yrds, 
                                                   'Fumbles_Returned_TD': recovered_fumbles_td, 
                                                   'Forced_Fumbles': forced_fumbles,
                                                   'Passing_Games': passing_games, 
                                                   'Completions': completions,
                                                   'Pass_Attempts': pass_attempts,
                                                   'Completion_Percent': complete_rate,
                                                   'Pass_Yards': passing_yards,
                                                   'Pass_Yds_per_Attempt': yds_per_attempt,
                                                   'Adj_Pass_Yds_per_Attempt': adj_yds_per_attempt,
                                                   'Pass_TDs': pass_tds,
                                                   'Pass_Interceptions': pass_ints,
                                                   'Passer_Rating': passer_rating,
                                                   'Rushing/Receiving_Games': rush_rec_games,
                                                   'Rush_Attempts': rushing_att,
                                                   'Rush_Yds': rushing_yds,
                                                   'Rush_Yds_per_Attempt': rushing_yds_per_att, 
                                                   'Rush_TDs': rushing_tds,
                                                   'Receptions': reception,
                                                   'Rec_Yds': rec_yards,
                                                   'Rec_Yds_per_Reception': yds_per_reception,
                                                   'Rec_TDs': td_receptions,
                                                   'Plays_from_Scrimmage': scrimmages,
                                                   'Scrimmage_Yds': scrimmage_yds,
                                                   'Scrimmage_Yds_per_Attempt': scrimmage_yds_per_att,
                                                   'Scrimmage_TDs': scrimmage_tds,
                                                   'Kicking_Games': kick_games,
                                                   'XP_Made': xp_made,
                                                   'XP_Attempts': xp_attempt,
                                                   'XP_Percent': xp_perc,
                                                   'FG_Made': field_goals,
                                                   'FG_Attempts': field_goals_att,
                                                   'FG_Percent': fg_percent,
                                                   'TTL_Kicking_Points': ttl_kick_pts,
                                                   '#Punts': punts,
                                                   'Punt_Yds': punt_yds,
                                                   'Yds_per_Punt': yds_per_punt,
                                                   'PuntRet_Games': puntret_games,
                                                   'Punt_Returns': ret_punts,
                                                   'Punt_Return_Yds': ret_punts_yds,
                                                   'Yrds_per_Return': yds_per_punt_return,
                                                   'Punt_Returned_for_TD': punt_ret_TD,
                                                   'Kickoff_Returns': kick_returns,
                                                   'KO_Return_Yds': kick_return_yds,
                                                   'Yds_per_KO_Return': yds_per_KO_ret,
                                                   'KO_Returned_for_TD': KO_ret_TD,
                                                   'Scoring_Games': scoring_games,
                                                   'TD_Other': other_tds,
                                                   'Ttl_TDs': total_tds,
                                                   '2PT_Converstions': two_pt_conv,
                                                   'Safety': safety,
                                                   'TTL_Points': ttl_pts  
                                                   },
                                                  ignore_index=True)

# %%
get_college_stats(college_stats[5401:])
# Out:
# HBox(children=(FloatProgress(value=0.0, max=85.0), HTML(value='')))

# %%
luke_url = 'https://www.sports-reference.com/cfb/players/luke-staley-1.html'

# %%
list(college_stats_df['Link'].tail())
# Out:
# ['https://www.sports-reference.com/cfb/players/jonathan-dwyer-1.html',
#  'https://www.sports-reference.com/cfb/players/marcus-easley-1.html',
#  'https://www.sports-reference.com/cfb/players/aj-edds-1.html',
#  'https://www.sports-reference.com/cfb/players/brody-eldridge-1.html',
#  'https://www.sports-reference.com/cfb/players/dedrick-epps-1.html']

# %%
print(college_stats[2357])
print(college_stats[2358])
# Out:
# https://www.sports-reference.com/cfb/players/dedrick-epps-1.html
# https://www.sports-reference.com/cfb/players/jacoby-ford-1.html

# %%
len(list(college_stats_df['Link']))
# Out:
# 5486

# %%
len(college_stats)
# Out:
# 5486

# %%
college_stats_df['Link'].value_counts()
# Out:
# https://www.sports-reference.com/cfb/players/david-long-3.html           2
# https://www.sports-reference.com/cfb/players/buster-davis-1.html         2
# https://www.sports-reference.com/cfb/players/derrick-johnson-3.html      2
# https://www.sports-reference.com/cfb/players/dalton-keene-1.html         1
# https://www.sports-reference.com/cfb/players/brandon-johnson-1.html      1
#                                                                         ..
# https://www.sports-reference.com/cfb/players/brandon-pace-1.html         1
# https://www.sports-reference.com/cfb/players/kendarius-webster-1.html    1
# https://www.sports-reference.com/cfb/players/adrian-amos-1.html          1
# https://www.sports-reference.com/cfb/players/chris-henry-1.html          1
# https://www.sports-reference.com/cfb/players/drew-lock-1.html            1
# Name: Link, Length: 5483, dtype: int64

# %%
college_stats_df.to_csv('college_stats_df_5486_rows.csv')

# %%
link_check = college_stats_df[['Link'], ]
link_check.head()
# Out:
#                                                 Link
# 0  https://www.sports-reference.com/cfb/players/s...
# 1  https://www.sports-reference.com/cfb/players/l...
# 2  https://www.sports-reference.com/cfb/players/j...
# 3  https://www.sports-reference.com/cfb/players/a...
# 4  https://www.sports-reference.com/cfb/players/t...

# %%
for i in link_check['Link']:
    if i in college_stats:
        link_check.append({'Check':'True'}, ignore_index=True)
    else:
        link_check.append({'Check': 'False'}, ignore_index=True)

# %%
links = pd.DataFrame(columns = ['List'])
links['List'] = [i for i in college_stats]
links
# Out:
#                                                    List
# 0     https://www.sports-reference.com/cfb/players/s...
# 1     https://www.sports-reference.com/cfb/players/l...
# 2     https://www.sports-reference.com/cfb/players/j...
# 3     https://www.sports-reference.com/cfb/players/a...
# 4     https://www.sports-reference.com/cfb/players/t...
# ...                                                 ...
# 5481  https://www.sports-reference.com/cfb/players/d...
# 5482  https://www.sports-reference.com/cfb/players/d...
# 5483  https://www.sports-reference.com/cfb/players/d...
# 5484  https://www.sports-reference.com/cfb/players/c...
# 5485  https://www.sports-reference.com/cfb/players/j...
#
# [5486 rows x 1 columns]

# %%
link_check = pd.DataFrame(columns = ['Link', 'List', 'Check'])
link_check['Link'] = college_stats_df['Link']
link_check['List'] = [i for i in college_stats]
link_check['Check'] = link_check['Link'] == link_check['List']
link_check['Check'].value_counts()
# Out:
# True    5486
# Name: Check, dtype: int64

# %%
def defense_container(soup):
        
    # defense container
    try:
        all_defense = soup.find('div', id='all_defense')
        for item in all_defense.children:
            if isinstance(item, bs4.element.Comment):
                html = item
        defense = BeautifulSoup(html, features="html.parser")
    except:
        html = ''
        defense = soup.find('div', id='all_defense')
        
    return defense

# %%
def passing_container(soup):

    # passing container
    try:
        all_passing = soup.find('div', id='all_passing')
        for item in all_passing.children:
            if isinstance(item, bs4.element.Comment):
                html = item
        passing = BeautifulSoup(html, features="html.parser")
    except:
        html = ''
        passing = soup.find('div', id='all_passing')
        
    return passing

# %%
def rushing_container(soup):

    # rushing container
    try:
        all_rushing = soup.find('div', id='all_rushing')
        for item in all_rushing.children:
            if isinstance(item, bs4.element.Comment):
                html = item
        rushing = BeautifulSoup(html, features="html.parser")
    except:
        html = ''
        rushing = soup.find('div', id='all_rushing')
        
    return rushing

# %%
def scoring_container(soup):
   
    # scoring container
    try:
        all_scoring = soup.find('div', id='all_scoring')
        for item in all_scoring.children:
            if isinstance(item, bs4.element.Comment):
                html = item
        scoring = BeautifulSoup(html, features="html.parser")
    except:
        html = ''
        scoring = soup.find('div', id='all_scoring')  
        
    return scoring

# %%
def kicking_container(soup):

    # punting container
    try:
        all_kicking = soup.find('div', id='all_kicking')
        for item in all_kicking.children:
            if isinstance(item, bs4.element.Comment):
                html = item
        kicking = BeautifulSoup(html, features="html.parser")
    except:
        html = ''
        kicking = soup.find('div', id='all_kicking')
        
    return kicking

# %%
def punt_ret_container(soup):
    
    # punt ret container
    try:
        all_punt_ret = soup.find('div', id='all_punt_ret')
        for item in all_punt_ret.children:
            if isinstance(item, bs4.element.Comment):
                html = item
        punt_ret = BeautifulSoup(html, features="html.parser")
    except:
        html = ''
        punt_ret = soup.find('div', id='all_punt_ret')
        
    return punt_ret
